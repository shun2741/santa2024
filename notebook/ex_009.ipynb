# %% [markdown]
# ### SAのテンプレート
# バッチサイズ分だけ並行して実施する

# %%
ex_num = "009"

# %%
import os
# 環境によって変更
os.chdir('/home/jovyan/work/notebook')

# %%
class CFG:
    path = "../model"    
    # path = "../../output"
    base_file_path = "../input/sub20241221.csv"
    
    # 焼きなましのパラメータ
    temperature=100
    end_temperature=0.1
    cooling_rate=0.9999
    iteration=int(1e6)
    batch_size=32
    neighbor_types = ["swap", "insert", "inverse", "slide"]

# %%
import numpy as np
import pandas as pd
import os
import time
import csv

from tqdm.notebook import tqdm

import random
from typing import List, Callable
import itertools, math
from typing import List, Tuple

from utils import PerplexityCalculator
# 可視化用
import matplotlib.pyplot as plt

# %% [markdown]
# ### データ読み込み

# %%
df = pd.read_csv(CFG.base_file_path)

# %%
sub_df = df.copy()
sub_df["best_value"] = 0

# %%
df
# Out:
#    id                                               text
# 0   0  reindeer mistletoe elf gingerbread family adve...
# 1   1  reindeer sleep walk the night and drive mistle...
# 2   2  jingle yuletide carol cheer holly stocking chi...
# 3   3  sleigh the holly jingle unwrap gifts of magi r...
# 4   4  peppermint candy milk chocolate eggnog fruitca...
# 5   5  poinsettia yuletide eggnog fruitcake gingerbre...

# %% [markdown]
# ### 関数

# %%
def plot_score_and_temperature(scores_history, temp_history):
    # x 軸: イテレーション
    x = range(len(scores_history))
    
    # Figure と Axes を作成
    fig, ax1 = plt.subplots(figsize=(8,5))
    
    # スコア用の軸 (左)
    color_score = 'tab:blue'
    ax1.set_xlabel('Iteration')
    ax1.set_ylabel('Score (Perplexity)', color=color_score)
    ax1.plot(x, scores_history, label='Score', color=color_score)
    ax1.tick_params(axis='y', labelcolor=color_score)
    
    # 温度用の軸 (右) : twinx で第二のY軸を作成
    ax2 = ax1.twinx()
    color_temp = 'tab:red'
    ax2.set_ylabel('Temperature', color=color_temp)
    ax2.plot(x, temp_history, label='Temperature', color=color_temp)
    ax2.tick_params(axis='y', labelcolor=color_temp)
    
    # タイトル等
    plt.title('Score & Temperature Transition')
    fig.tight_layout()
    plt.show()

# %%
# 2単語組み合わせ全てから最低スコアとなるペアを探す
def find_initial_pair(
    CFG,
    scorer,
    words
):
    best_score = float('inf')
    best_pair = None
    for i in range(len(words)):
        perms = []
        for j in range(i+1, len(words)):
            pair = [words[i], words[j]]
            perms.append(" ".join(pair))
        
        scores = scorer.get_perplexity(perms, batch_size=CFG.batch_size)
        for j, perm in enumerate(perms):
            if scores[j] < best_score:
                best_score = scores[j]
                best_pair = perm.split(" ")
                
                # print(f"best_score: {best_score}, best_pair: {best_pair}")
     
    return best_pair, best_score

# %%
# 文字の順番をランダムにして、返す
def shuffle_initialize(
    scorer,
    words
):
    random.shuffle(words)
    return words, scorer.get_perplexity([" ".join(words)], batch_size=1)[0]

# %%
# 文字列のファイルからコストを最小化する文字列を生成する
def greedy_add_initialize(
    CFG,
    scorer,
    initial_words: list
):
    
    # 全単語
    candidates = initial_words[:]

    print("candidates:", candidates)
    print("-----初期配置の組み合わせ計算開始-----")
    # 初期配置を求める
    initial, initial_score = find_initial_pair(
        CFG,
        scorer,
        candidates
    )
    print("-----初期配置の組み合わせ計算終了-----")
    for w in initial:
        candidates.remove(w)

    print("initial:", initial, initial_score)
    current_order = initial[:]

    print("-----貪欲法での挿入開始-----")
    # 貪欲に残りを挿入
    while candidates:
        best_score = float('inf')
        best_word = None
        best_pos = None

        # 残っている単語それぞれについて
        for w in candidates:
            # current_orderのあらゆる挿入位置を試す
            # 挿入位置は0からlen(current_order)まで
            
            perms = []
            for pos in range(len(current_order) + 1):
                new_order = current_order[:pos] + [w] + current_order[pos:]
                perms.append(" ".join(new_order))
                
            scores = scorer.get_perplexity(perms, batch_size=CFG.BATCH_SIZE)
                
            for pos in range(len(current_order) + 1):
                if scores[pos] < best_score:
                    best_score = scores[pos]
                    best_word = w
                    best_pos = pos
                    
                    # print("best_word:", best_word, best_score)
        
        # best_wordをbest_posに挿入
        current_order.insert(best_pos, best_word)
        candidates.remove(best_word)
        print("current_order:", current_order, best_score)
    print("-----貪欲法での挿入終了-----")
    
    best_score = scorer.get_perplexity([" ".join(current_order)], batch_size=1)[0]
    
    return current_order, best_score

# %%
def generate_neighbor(sequence, neighbor_type='swap'):
    """
    sequence: list of words
    neighbor_type: str, 近傍生成の種類 ('swap', 'insert', etc.)
    """
    new_seq = sequence[:]
    length = len(new_seq)

    if neighbor_type == 'swap':
        # ランダムに2つの位置を選んで入れ替える
        a, b = random.sample(range(length), 2)
        new_seq[a], new_seq[b] = new_seq[b], new_seq[a]

    elif neighbor_type == 'insert':
        # ある単語を抜き出し、別の位置に挿入する
        idx = random.randint(0, length - 1)
        word = new_seq.pop(idx)
        new_pos = random.randint(0, length - 1)
        new_seq.insert(new_pos, word)

    elif neighbor_type == 'shuffle_segment':
        # ランダムな部分区間を決めてシャッフル
        start = random.randint(0, length - 2)
        end = random.randint(start + 1, length - 1)
        segment = new_seq[start:end+1]
        random.shuffle(segment)
        new_seq[start:end+1] = segment

    elif neighbor_type == 'reverse_segment':
        # ランダムな部分区間を決めて反転
        start = random.randint(0, length - 2)
        end = random.randint(start + 1, length - 1)
        segment = new_seq[start:end+1]
        new_seq[start:end+1] = list(reversed(segment))

    # 他にも様々な近傍操作を追加可能

    return new_seq

# %%
def search_annealing(
    scorer,
    initial_sequence,
    temperature: float = 1.0,
    end_temperature: float = 0.01,
    cooling_rate: float = 0.999,
    iteration: int = 1000,
    batch_size: int = 10,
    neighbor_types: list = None
):
    """
    焼きなまし法による探索

    Parameters
    ----------
    CFG: 設定用（必要に応じて）
    scorer: perplexityを計算できるオブジェクト
    initial_sequence: 初期の単語リスト
    temperature: 開始時の温度
    cooling_rate: 温度の減少率
    iteration: 探索の反復回数
    batch_size: 1ステップで生成する近傍候補の数
    neighbor_types: 近傍生成の種類を指定するリスト
    """
    if neighbor_types is None:
        neighbor_types = ['swap', 'insert', 'shuffle_segment', 'reverse_segment']

    # 初期状態
    current_seq = initial_sequence[:]
    best_seq = current_seq[:]
    best_score = scorer.get_perplexity([" ".join(current_seq)], batch_size=1)[0]

    # current_scoreの計算
    current_score = best_score

    # スコア推移を記録するリスト
    scores_history = []
    temp_history = []
    
    # 現在の状態を持つリスト
    current_seqs = []
    current_scores = []
    
    # 初期解の生成
    for _ in range(CFG.batch_size):
        print("current_seq:", current_seq)
        print("current_score:", current_score)
        current_seq, current_score = shuffle_initialize(
            scorer,
            current_seq,
        )
        current_seqs.append(current_seq)
        current_scores.append(current_score)
        
    for itr in tqdm(range(iteration)):
        # 記録（ループの冒頭 or 最後のどちらでもOK）
        scores_history.append(current_scores[0])
        temp_history.append(temperature)
        
        # 近傍候補をまとめて生成
        neighbor_candidates = []
        for i in range(CFG.batch_size):
            # 近傍操作の種類をランダムに選ぶ
            n_type = random.choice(neighbor_types)
            neighbor_seq = generate_neighbor(current_seqs[i], n_type)
            neighbor_candidates.append(neighbor_seq)

        
        # まとめてスコアを計算（GPUを活用）
        texts = [" ".join(seq) for seq in neighbor_candidates]
        # print("texts:", texts)
        
        scores = scorer.get_perplexity(texts, batch_size=batch_size)
        # print("scores:", scores)
        
        # 候補の中から1つを焼きなまし法の確率的受容ルールで選ぶ
        for i, (cand_seq, cand_score) in enumerate(zip(neighbor_candidates, scores)):
            delta = cand_score - current_scores[i]
            accept_prob = math.exp(-delta / temperature) if delta > 0 else 1.0
                
            # スコアが良ければ必ず受容
            if (itr==0) or (random.random() < accept_prob):
                current_scores[i] = cand_score
                current_seqs[i] = cand_seq

        # ベストの更新
        # currnet_scoresのリストの最小値を取得
        if np.min(current_scores) < best_score:
            # current_scoresの最小値のインデックスを取得
            idx = np.argmin(current_scores)
            
            best_score = current_scores[idx]
            best_seq = current_seqs[idx]
            print(f"iter {itr}: best_score: {best_score}")
            print("best_seq:", best_seq)

        # 温度を下げる
        if itr % 10 == 0:
            temperature *= cooling_rate
        
        if itr % 10 == 0:
            print(f"iter :{itr}, best_score: {best_score}, temperature: {temperature}")

            # current_seqsを結合して文字列保存
            current_seqs_text = [" ".join(seq) for seq in current_seqs]
            # current_seqsとcurrent_scoresのリストをdfとして保存
            df = pd.DataFrame(current_seqs_text)
            df["score"] = current_scores
            
            # indexとなっていたものをsequencre列に変更
            df = df.reset_index()
            df = df.rename(columns={"index": "sequence"})
            
            df.to_csv(f"current_texts.csv", index=False)
        if temperature < end_temperature:
            break
        
    return best_seq, best_score, scores_history, temp_history

# %%
def search_optimal_permutation(
    CFG,
    id: int, 
    scorer
):
    
    df = pd.read_csv(CFG.base_file_path)
    
    start = time.time()
    # 文字列を単語に分割
    words = df.loc[id,"text"].split()
    
    initial_sequence = words[:]
    print("--------初期配置の組み合わせ計算開始---------")
    initial_sequence, initial_score = shuffle_initialize(
        scorer=scorer,
        words=words
    )
    
    print(f"{id}th sample: {initial_sequence}")
    print(f"Elapsed time: {time.time() - start:.2f} sec")
    print(f"initial_score: {initial_score}")
    print("--------初期配置の組み合わせ計算終了---------")
    
    print("---------焼きなまし処理開始---------")
    best_sequence, best_score, scores_history, temp_history = search_annealing(
        scorer=scorer,
        initial_sequence=initial_sequence,
        temperature=CFG.temperature,
        end_temperature=CFG.end_temperature,
        cooling_rate=CFG.cooling_rate,
        iteration=CFG.iteration,
        batch_size=CFG.batch_size,
        neighbor_types=CFG.neighbor_types
    )
    print("---------焼きなまし処理終了---------")
    
    print(f"{id}th sample: {best_sequence}")
    print(f"Elapsed time: {time.time() - start:.2f} sec")
    print(f"best_score: {best_score}")
    
    plot_score_and_temperature(scores_history, temp_history)
    
    return best_sequence, best_score

# %%
# 文字列型にのみダブルクォーテーションを付ける関数
def add_quotes_to_strings(value):
    if isinstance(value, str):  # 文字列型の場合
        return f'"{value}"'
    return value  # それ以外はそのまま

# %%
# LOAD GEMMA SCORER
scorer = PerplexityCalculator(f'{CFG.path}/gemma_2_9b')
# Out:
# cuda
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Some parameters are on the meta device because they were offloaded to the cpu.

# %%
# scorer.clear_gpu_memory()

# %%
for i in [2]:
    
    print(f"Processing {i}th sample")
    best_sequence, best_score = search_optimal_permutation(
        CFG,
        id=i,
        scorer=scorer,
    )
    
    print("Best sequence:", best_sequence)
    print("Best score:", best_score)
    sub_df.loc[i, "best_value"] = best_score
    sub_df.loc[i, "text"] = " ".join(best_sequence)
# Out:
# Processing 2th sample
# --------初期配置の組み合わせ計算開始---------
# 2th sample: ['grinch', 'sleigh', 'magi', 'carol', 'naughty', 'nutcracker', 'cheer', 'stocking', 'holly', 'jingle', 'decorations', 'yuletide', 'gifts', 'ornament', 'polar', 'workshop', 'nice', 'holiday', 'beard', 'chimney']
# Elapsed time: 1.16 sec
# initial_score: 1564.7302908385489
# --------初期配置の組み合わせ計算終了---------
# ---------焼きなまし処理開始---------
# current_seq: ['grinch', 'sleigh', 'magi', 'carol', 'naughty', 'nutcracker', 'cheer', 'stocking', 'holly', 'jingle', 'decorations', 'yuletide', 'gifts', 'ornament', 'polar', 'workshop', 'nice', 'holiday', 'beard', 'chimney']
# current_score: 1564.7302908385489
# current_seq: ['yuletide', 'cheer', 'decorations', 'nice', 'holly', 'magi', 'polar', 'naughty', 'chimney', 'gifts', 'sleigh', 'beard', 'grinch', 'workshop', 'holiday', 'stocking', 'jingle', 'nutcracker', 'carol', 'ornament']
# current_score: 2452.0691545936147
# current_seq: ['yuletide', 'chimney', 'carol', 'sleigh', 'polar', 'jingle', 'holiday', 'grinch', 'beard', 'naughty', 'cheer', 'stocking', 'holly', 'workshop', 'ornament', 'magi', 'nutcracker', 'nice', 'gifts', 'decorations']
# current_score: 2130.3946005086336
# current_seq: ['yuletide', 'sleigh', 'cheer', 'workshop', 'chimney', 'decorations', 'naughty', 'polar', 'stocking', 'ornament', 'carol', 'nutcracker', 'holly', 'holiday', 'jingle', 'nice', 'magi', 'grinch', 'beard', 'gifts']
# current_score: 3273.9418610498587
# current_seq: ['yuletide', 'stocking', 'nice', 'magi', 'holly', 'holiday', 'gifts', 'sleigh', 'cheer', 'ornament', 'grinch', 'nutcracker', 'carol', 'chimney', 'beard', 'naughty', 'jingle', 'workshop', 'polar', 'decorations']
# current_score: 3768.283983397487
# current_seq: ['sleigh', 'stocking', 'yuletide', 'decorations', 'cheer', 'nice', 'nutcracker', 'ornament', 'holly', 'magi', 'holiday', 'beard', 'workshop', 'jingle', 'naughty', 'polar', 'gifts', 'carol', 'grinch', 'chimney']
# current_score: 1601.8368003527937
# current_seq: ['ornament', 'magi', 'carol', 'holiday', 'naughty', 'decorations', 'gifts', 'nutcracker', 'sleigh', 'holly', 'beard', 'polar', 'cheer', 'yuletide', 'chimney', 'nice', 'grinch', 'stocking', 'jingle', 'workshop']
# current_score: 1685.2808408062344
# current_seq: ['sleigh', 'nice', 'workshop', 'yuletide', 'carol', 'holly', 'polar', 'nutcracker', 'decorations', 'cheer', 'grinch', 'beard', 'naughty', 'gifts', 'jingle', 'magi', 'holiday', 'chimney', 'ornament', 'stocking']
# current_score: 2163.9434338520923
# current_seq: ['ornament', 'grinch', 'holly', 'carol', 'yuletide', 'jingle', 'magi', 'beard', 'gifts', 'workshop', 'sleigh', 'naughty', 'chimney', 'nice', 'cheer', 'nutcracker', 'holiday', 'decorations', 'stocking', 'polar']
# current_score: 1100.9252592553103
# current_seq: ['chimney', 'decorations', 'workshop', 'holiday', 'carol', 'jingle', 'gifts', 'nice', 'naughty', 'yuletide', 'polar', 'nutcracker', 'stocking', 'sleigh', 'holly', 'cheer', 'grinch', 'magi', 'ornament', 'beard']
# current_score: 2610.214027948303
# current_seq: ['holiday', 'nice', 'polar', 'holly', 'grinch', 'chimney', 'carol', 'decorations', 'stocking', 'nutcracker', 'jingle', 'naughty', 'ornament', 'gifts', 'yuletide', 'workshop', 'beard', 'sleigh', 'cheer', 'magi']
# current_score: 5070.780350360642
# current_seq: ['holiday', 'ornament', 'holly', 'nutcracker', 'stocking', 'decorations', 'gifts', 'beard', 'carol', 'chimney', 'polar', 'sleigh', 'magi', 'nice', 'naughty', 'jingle', 'grinch', 'cheer', 'workshop', 'yuletide']
# current_score: 5150.633521625214
# current_seq: ['magi', 'grinch', 'stocking', 'decorations', 'nutcracker', 'holly', 'polar', 'workshop', 'beard', 'chimney', 'nice', 'sleigh', 'jingle', 'cheer', 'gifts', 'carol', 'naughty', 'yuletide', 'ornament', 'holiday']
# current_score: 2009.1534636978986
# current_seq: ['yuletide', 'polar', 'nutcracker', 'grinch', 'magi', 'sleigh', 'holiday', 'beard', 'stocking', 'chimney', 'cheer', 'nice', 'ornament', 'decorations', 'jingle', 'carol', 'gifts', 'workshop', 'naughty', 'holly']
# current_score: 2529.90618498386
# current_seq: ['beard', 'nutcracker', 'holiday', 'magi', 'holly', 'grinch', 'decorations', 'polar', 'ornament', 'yuletide', 'nice', 'cheer', 'sleigh', 'chimney', 'jingle', 'workshop', 'stocking', 'gifts', 'carol', 'naughty']
# current_score: 3099.705853489035
# current_seq: ['beard', 'cheer', 'stocking', 'decorations', 'yuletide', 'workshop', 'magi', 'gifts', 'ornament', 'nice', 'nutcracker', 'grinch', 'polar', 'holly', 'holiday', 'jingle', 'sleigh', 'chimney', 'naughty', 'carol']
# current_score: 4763.55729978668
# current_seq: ['yuletide', 'naughty', 'cheer', 'stocking', 'chimney', 'ornament', 'workshop', 'jingle', 'holiday', 'grinch', 'sleigh', 'beard', 'nutcracker', 'holly', 'gifts', 'nice', 'decorations', 'carol', 'magi', 'polar']
# current_score: 4203.824562345984
# current_seq: ['workshop', 'sleigh', 'holiday', 'yuletide', 'naughty', 'ornament', 'nutcracker', 'grinch', 'polar', 'holly', 'stocking', 'nice', 'decorations', 'magi', 'chimney', 'carol', 'beard', 'cheer', 'jingle', 'gifts']
# current_score: 4106.443071244924
# current_seq: ['decorations', 'naughty', 'workshop', 'nice', 'jingle', 'ornament', 'gifts', 'sleigh', 'cheer', 'yuletide', 'carol', 'polar', 'holiday', 'nutcracker', 'stocking', 'holly', 'magi', 'chimney', 'beard', 'grinch']
# current_score: 2017.01706801857
# current_seq: ['cheer', 'yuletide', 'nice', 'grinch', 'jingle', 'stocking', 'naughty', 'workshop', 'gifts', 'polar', 'holly', 'carol', 'holiday', 'magi', 'sleigh', 'ornament', 'chimney', 'nutcracker', 'decorations', 'beard']
# current_score: 2844.4499822093103
# current_seq: ['sleigh', 'holly', 'nice', 'workshop', 'decorations', 'ornament', 'beard', 'carol', 'nutcracker', 'magi', 'cheer', 'grinch', 'chimney', 'naughty', 'stocking', 'polar', 'yuletide', 'gifts', 'holiday', 'jingle']
# current_score: 3512.4268928432866
# current_seq: ['carol', 'chimney', 'beard', 'jingle', 'stocking', 'nice', 'polar', 'nutcracker', 'gifts', 'yuletide', 'holiday', 'cheer', 'decorations', 'naughty', 'workshop', 'sleigh', 'ornament', 'grinch', 'magi', 'holly']
# current_score: 7732.016698600223
# current_seq: ['jingle', 'yuletide', 'workshop', 'gifts', 'magi', 'holly', 'ornament', 'chimney', 'polar', 'grinch', 'sleigh', 'nutcracker', 'beard', 'naughty', 'holiday', 'cheer', 'carol', 'nice', 'decorations', 'stocking']
# current_score: 1242.6481670549958
# current_seq: ['polar', 'holly', 'beard', 'yuletide', 'holiday', 'jingle', 'decorations', 'chimney', 'gifts', 'cheer', 'workshop', 'ornament', 'magi', 'grinch', 'nutcracker', 'naughty', 'sleigh', 'stocking', 'carol', 'nice']
# current_score: 4011.317419955544
# current_seq: ['nice', 'gifts', 'polar', 'workshop', 'beard', 'yuletide', 'ornament', 'sleigh', 'decorations', 'stocking', 'cheer', 'jingle', 'grinch', 'nutcracker', 'carol', 'naughty', 'chimney', 'holiday', 'magi', 'holly']
# current_score: 6360.183448360342
# current_seq: ['naughty', 'grinch', 'holly', 'beard', 'nutcracker', 'cheer', 'workshop', 'chimney', 'stocking', 'holiday', 'gifts', 'magi', 'polar', 'sleigh', 'decorations', 'yuletide', 'ornament', 'jingle', 'nice', 'carol']
# current_score: 3567.7395679838205
# current_seq: ['holly', 'gifts', 'holiday', 'carol', 'sleigh', 'nutcracker', 'stocking', 'workshop', 'jingle', 'ornament', 'naughty', 'polar', 'cheer', 'grinch', 'nice', 'chimney', 'beard', 'decorations', 'magi', 'yuletide']
# current_score: 4440.123631628586
# current_seq: ['sleigh', 'nice', 'holiday', 'naughty', 'magi', 'grinch', 'nutcracker', 'yuletide', 'workshop', 'jingle', 'carol', 'beard', 'decorations', 'holly', 'polar', 'ornament', 'chimney', 'gifts', 'stocking', 'cheer']
# current_score: 2822.314296832108
# current_seq: ['nutcracker', 'gifts', 'workshop', 'sleigh', 'holiday', 'ornament', 'stocking', 'holly', 'chimney', 'beard', 'naughty', 'yuletide', 'cheer', 'magi', 'decorations', 'polar', 'jingle', 'carol', 'nice', 'grinch']
# current_score: 2276.66913936313
# current_seq: ['gifts', 'workshop', 'chimney', 'sleigh', 'nutcracker', 'naughty', 'nice', 'cheer', 'jingle', 'polar', 'stocking', 'carol', 'grinch', 'magi', 'holly', 'ornament', 'yuletide', 'beard', 'holiday', 'decorations']
# current_score: 3273.9418610498587
# current_seq: ['nice', 'chimney', 'workshop', 'holly', 'jingle', 'carol', 'yuletide', 'magi', 'nutcracker', 'decorations', 'polar', 'stocking', 'cheer', 'sleigh', 'gifts', 'naughty', 'grinch', 'beard', 'holiday', 'ornament']
# current_score: 10734.842085952703
# current_seq: ['polar', 'magi', 'naughty', 'cheer', 'holiday', 'nice', 'gifts', 'jingle', 'holly', 'chimney', 'beard', 'yuletide', 'stocking', 'nutcracker', 'decorations', 'grinch', 'carol', 'sleigh', 'workshop', 'ornament']
# current_score: 7150.946467468294
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# iter 0: best_score: 1522.524360828172
# best_seq: ['ornament', 'sleigh', 'decorations', 'grinch', 'gifts', 'nutcracker', 'magi', 'holly', 'naughty', 'polar', 'carol', 'workshop', 'jingle', 'beard', 'nice', 'cheer', 'holiday', 'yuletide', 'stocking', 'chimney']
# iter :0, best_score: 1522.524360828172, temperature: 99.99
# iter 1: best_score: 1441.4970923843368
# best_seq: ['ornament', 'decorations', 'grinch', 'gifts', 'nutcracker', 'magi', 'holly', 'naughty', 'stocking', 'carol', 'workshop', 'jingle', 'beard', 'nice', 'cheer', 'holiday', 'sleigh', 'yuletide', 'polar', 'chimney']
# iter 4: best_score: 1380.8696350453124
# best_seq: ['ornament', 'sleigh', 'decorations', 'grinch', 'gifts', 'nutcracker', 'magi', 'carol', 'holly', 'stocking', 'naughty', 'workshop', 'jingle', 'beard', 'nice', 'cheer', 'holiday', 'yuletide', 'chimney', 'polar']
# iter 6: best_score: 1242.6481670549958
# best_seq: ['sleigh', 'ornament', 'decorations', 'grinch', 'gifts', 'nutcracker', 'magi', 'carol', 'holly', 'stocking', 'naughty', 'workshop', 'jingle', 'beard', 'nice', 'cheer', 'holiday', 'yuletide', 'chimney', 'polar']
# iter 9: best_score: 1105.234158889827
# best_seq: ['ornament', 'decorations', 'grinch', 'gifts', 'nutcracker', 'stocking', 'magi', 'holly', 'naughty', 'sleigh', 'carol', 'cheer', 'jingle', 'beard', 'nice', 'workshop', 'holiday', 'yuletide', 'polar', 'chimney']
# iter 10: best_score: 1058.7494748958482
# best_seq: ['ornament', 'grinch', 'gifts', 'magi', 'holly', 'naughty', 'nice', 'yuletide', 'decorations', 'stocking', 'carol', 'workshop', 'jingle', 'beard', 'sleigh', 'nutcracker', 'cheer', 'holiday', 'polar', 'chimney']
# iter :10, best_score: 1058.7494748958482, temperature: 99.980001
# iter :20, best_score: 1058.7494748958482, temperature: 99.9700029999
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 4
#       1 for i in [2]:
#       3     print(f"Processing {i}th sample")
# ----> 4     best_sequence, best_score = search_optimal_permutation(
#       5         CFG,
#       6         id=i,
#       7         scorer=scorer,
#       8     )
#      10     print("Best sequence:", best_sequence)
#      11     print("Best score:", best_score)
#
# Cell In[14], line 26, in search_optimal_permutation(CFG, id, scorer)
#      23 print("--------初期配置の組み合わせ計算終了---------")
#      25 print("---------焼きなまし処理開始---------")
# ---> 26 best_sequence, best_score, scores_history, temp_history = search_annealing(
#      27     scorer=scorer,
#      28     initial_sequence=initial_sequence,
#      29     temperature=CFG.temperature,
#      30     end_temperature=CFG.end_temperature,
#      31     cooling_rate=CFG.cooling_rate,
#      32     iteration=CFG.iteration,
#      33     batch_size=CFG.batch_size,
#      34     neighbor_types=CFG.neighbor_types
#      35 )
#      36 print("---------焼きなまし処理終了---------")
#      38 print(f"{id}th sample: {best_sequence}")
#
# Cell In[13], line 73, in search_annealing(scorer, initial_sequence, temperature, end_temperature, cooling_rate, iteration, batch_size, neighbor_types)
#      70 texts = [" ".join(seq) for seq in neighbor_candidates]
#      71 # print("texts:", texts)
# ---> 73 scores = scorer.get_perplexity(texts, batch_size=batch_size)
#      74 # print("scores:", scores)
#      75
#      76 # 候補の中から1つを焼きなまし法の確率的受容ルールで選ぶ
#      77 for i, (cand_seq, cand_score) in enumerate(zip(neighbor_candidates, scores)):
#
# File /home/jovyan/work/notebook/utils.py:249, in PerplexityCalculator.get_perplexity(self, input_texts, batch_size)
#     246 model_inputs = {k: v.to(DEVICE) for k, v in model_inputs.items()}
#     248 # Get model output
# --> 249 output = self.model(**model_inputs, use_cache=False)
#     250 logits = output['logits']
#     252 label = model_inputs['input_ids']
#
# File /usr/local/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /usr/local/lib/python3.12/site-packages/accelerate/hooks.py:170, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     168         output = module._old_forward(*args, **kwargs)
#     169 else:
# --> 170     output = module._old_forward(*args, **kwargs)
#     171 return module._hf_hook.post_forward(module, output)
#
# File /usr/local/lib/python3.12/site-packages/transformers/models/gemma2/modeling_gemma2.py:977, in Gemma2ForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, num_logits_to_keep, **loss_kwargs)
#     975 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     976 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# --> 977 outputs = self.model(
#     978     input_ids=input_ids,
#     979     attention_mask=attention_mask,
#     980     position_ids=position_ids,
#     981     past_key_values=past_key_values,
#     982     inputs_embeds=inputs_embeds,
#     983     use_cache=use_cache,
#     984     output_attentions=output_attentions,
#     985     output_hidden_states=output_hidden_states,
#     986     return_dict=return_dict,
#     987     cache_position=cache_position,
#     988 )
#     990 hidden_states = outputs[0]
#     991 # Only compute necessary logits, and do not upcast them to float if we are not computing the loss
#
# File /usr/local/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /usr/local/lib/python3.12/site-packages/transformers/models/gemma2/modeling_gemma2.py:763, in Gemma2Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     752     layer_outputs = self._gradient_checkpointing_func(
#     753         decoder_layer.__call__,
#     754         hidden_states,
#    (...)
#     760         cache_position,
#     761     )
#     762 else:
# --> 763     layer_outputs = decoder_layer(
#     764         hidden_states,
#     765         attention_mask=causal_mask,
#     766         position_ids=position_ids,
#     767         past_key_value=past_key_values,
#     768         output_attentions=output_attentions,
#     769         use_cache=use_cache,
#     770         cache_position=cache_position,
#     771     )
#     773 hidden_states = layer_outputs[0]
#     775 if output_attentions:
#
# File /usr/local/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /usr/local/lib/python3.12/site-packages/accelerate/hooks.py:170, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     168         output = module._old_forward(*args, **kwargs)
#     169 else:
# --> 170     output = module._old_forward(*args, **kwargs)
#     171 return module._hf_hook.post_forward(module, output)
#
# File /usr/local/lib/python3.12/site-packages/transformers/models/gemma2/modeling_gemma2.py:493, in Gemma2DecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position)
#     491 residual = hidden_states
#     492 hidden_states = self.pre_feedforward_layernorm(hidden_states)
# --> 493 hidden_states = self.mlp(hidden_states)
#     494 hidden_states = self.post_feedforward_layernorm(hidden_states)
#     495 hidden_states = residual + hidden_states
#
# File /usr/local/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /usr/local/lib/python3.12/site-packages/accelerate/hooks.py:170, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     168         output = module._old_forward(*args, **kwargs)
#     169 else:
# --> 170     output = module._old_forward(*args, **kwargs)
#     171 return module._hf_hook.post_forward(module, output)
#
# File /usr/local/lib/python3.12/site-packages/transformers/models/gemma2/modeling_gemma2.py:95, in Gemma2MLP.forward(self, x)
#      94 def forward(self, x):
# ---> 95     return self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
#
# File /usr/local/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /usr/local/lib/python3.12/site-packages/accelerate/hooks.py:165, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164 def new_forward(module, *args, **kwargs):
# --> 165     args, kwargs = module._hf_hook.pre_forward(module, *args, **kwargs)
#     166     if module._hf_hook.no_grad:
#     167         with torch.no_grad():
#
# File /usr/local/lib/python3.12/site-packages/accelerate/hooks.py:355, in AlignDevicesHook.pre_forward(self, module, *args, **kwargs)
#     347         if (
#     348             value is not None
#     349             and self.tied_params_map is not None
#     350             and value.data_ptr() in self.tied_params_map
#     351             and self.execution_device not in self.tied_params_map[value.data_ptr()]
#     352         ):
#     353             self.tied_pointers_to_remove.add((value.data_ptr(), self.execution_device))
# --> 355         set_module_tensor_to_device(
#     356             module,
#     357             name,
#     358             self.execution_device,
#     359             value=value,
#     360             fp16_statistics=fp16_statistics,
#     361             tied_params_map=self.tied_params_map,
#     362         )
#     364 return send_to_device(args, self.execution_device), send_to_device(
#     365     kwargs, self.execution_device, skip_keys=self.skip_keys
#     366 )
#
# File /usr/local/lib/python3.12/site-packages/accelerate/utils/modeling.py:329, in set_module_tensor_to_device(module, tensor_name, device, value, dtype, fp16_statistics, tied_params_map)
#     327             module._parameters[tensor_name] = param_cls(new_value, requires_grad=old_value.requires_grad)
#     328 elif isinstance(value, torch.Tensor):
# --> 329     new_value = value.to(device)
#     330 else:
#     331     new_value = torch.tensor(value, device=device)
#
# KeyboardInterrupt:

# %%
sub_df
# Out:
#    id                                               text  best_value
# 0   0  reindeer mistletoe elf gingerbread family adve...    0.000000
# 1   1  reindeer sleep walk the night and drive mistle...    0.000000
# 2   2  magi yuletide cheer grinch carol holiday holly...  302.154205
# 3   3  sleigh the holly jingle unwrap gifts of magi r...    0.000000
# 4   4  peppermint candy milk chocolate eggnog fruitca...    0.000000
# 5   5  poinsettia yuletide eggnog fruitcake gingerbre...    0.000000

# %%
# 各セルに関数を適用
sub_df["text"] = sub_df["text"].astype(str)
sub_df = sub_df.applymap(add_quotes_to_strings)
# Out:
# /tmp/ipykernel_309/428122046.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   sub_df = sub_df.applymap(add_quotes_to_strings)

# %%
sub_df[["id", "text"]].to_csv(f"{CFG.path}/out/submission_{ex_num}.csv", index=False, header=True, quoting=csv.QUOTE_NONE)
sub_df.to_csv(f"{CFG.path}/out/score_{ex_num}.csv", index=False, header=True, quoting=csv.QUOTE_NONE)

# %%
np.mean(sub_df["best_value"])
# Out:
# np.float64(50.359034184825845)
