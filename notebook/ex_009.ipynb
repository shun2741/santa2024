# %% [markdown]
# ### SAのテンプレート
# バッチサイズ分だけ並行して実施する

# %%
ex_num = "009"

# %%
import os
# 環境によって変更
# os.chdir('/home/jovyan/work/notebook')

# %%
class CFG:
    # path = "../model"    
    path = "../../output"
    base_file_path = "../input/sub20241221.csv"
    
    # 焼きなましのパラメータ
    temperature=100
    end_temperature=0.01
    cooling_rate=0.9999
    iteration=int(1e7)
    batch_size=32
    neighbor_types = ["swap", "insert", "inverse", "slide"]

# %%
import numpy as np
import pandas as pd
import os
import time
import csv

from tqdm.notebook import tqdm

import random
from typing import List, Callable
import itertools, math
from typing import List, Tuple

from utils import PerplexityCalculator
# 可視化用
import matplotlib.pyplot as plt

# %% [markdown]
# ### データ読み込み

# %%
df = pd.read_csv(CFG.base_file_path)

# %%
sub_df = df.copy()
sub_df["best_value"] = 0

# %%
df
# Out:
#    id                                               text
# 0   0  reindeer mistletoe elf gingerbread family adve...
# 1   1  reindeer sleep walk the night and drive mistle...
# 2   2  jingle yuletide carol cheer holly stocking chi...
# 3   3  sleigh the holly jingle unwrap gifts of magi r...
# 4   4  peppermint candy milk chocolate eggnog fruitca...
# 5   5  poinsettia yuletide eggnog fruitcake gingerbre...

# %% [markdown]
# ### 関数

# %%
def plot_score_and_temperature(scores_history, temp_history):
    # x 軸: イテレーション
    x = range(len(scores_history))
    
    # Figure と Axes を作成
    fig, ax1 = plt.subplots(figsize=(8,5))
    
    # スコア用の軸 (左)
    color_score = 'tab:blue'
    ax1.set_xlabel('Iteration')
    ax1.set_ylabel('Score (Perplexity)', color=color_score)
    ax1.plot(x, scores_history, label='Score', color=color_score)
    ax1.tick_params(axis='y', labelcolor=color_score)
    
    # 温度用の軸 (右) : twinx で第二のY軸を作成
    ax2 = ax1.twinx()
    color_temp = 'tab:red'
    ax2.set_ylabel('Temperature', color=color_temp)
    ax2.plot(x, temp_history, label='Temperature', color=color_temp)
    ax2.tick_params(axis='y', labelcolor=color_temp)
    
    # タイトル等
    plt.title('Score & Temperature Transition')
    fig.tight_layout()
    plt.show()

# %%
# 2単語組み合わせ全てから最低スコアとなるペアを探す
def find_initial_pair(
    CFG,
    scorer,
    words
):
    best_score = float('inf')
    best_pair = None
    for i in range(len(words)):
        perms = []
        for j in range(i+1, len(words)):
            pair = [words[i], words[j]]
            perms.append(" ".join(pair))
        
        scores = scorer.get_perplexity(perms, batch_size=CFG.batch_size)
        for j, perm in enumerate(perms):
            if scores[j] < best_score:
                best_score = scores[j]
                best_pair = perm.split(" ")
                
                # print(f"best_score: {best_score}, best_pair: {best_pair}")
     
    return best_pair, best_score

# %%
# 文字の順番をランダムにして、返す
def shuffle_initialize(
    scorer,
    words
):
    random.shuffle(words)
    return words, scorer.get_perplexity([" ".join(words)], batch_size=1)[0]

# %%
# 文字列のファイルからコストを最小化する文字列を生成する
def greedy_add_initialize(
    CFG,
    scorer,
    initial_words: list
):
    
    # 全単語
    candidates = initial_words[:]

    print("candidates:", candidates)
    print("-----初期配置の組み合わせ計算開始-----")
    # 初期配置を求める
    initial, initial_score = find_initial_pair(
        CFG,
        scorer,
        candidates
    )
    print("-----初期配置の組み合わせ計算終了-----")
    for w in initial:
        candidates.remove(w)

    print("initial:", initial, initial_score)
    current_order = initial[:]

    print("-----貪欲法での挿入開始-----")
    # 貪欲に残りを挿入
    while candidates:
        best_score = float('inf')
        best_word = None
        best_pos = None

        # 残っている単語それぞれについて
        for w in candidates:
            # current_orderのあらゆる挿入位置を試す
            # 挿入位置は0からlen(current_order)まで
            
            perms = []
            for pos in range(len(current_order) + 1):
                new_order = current_order[:pos] + [w] + current_order[pos:]
                perms.append(" ".join(new_order))
                
            scores = scorer.get_perplexity(perms, batch_size=CFG.BATCH_SIZE)
                
            for pos in range(len(current_order) + 1):
                if scores[pos] < best_score:
                    best_score = scores[pos]
                    best_word = w
                    best_pos = pos
                    
                    # print("best_word:", best_word, best_score)
        
        # best_wordをbest_posに挿入
        current_order.insert(best_pos, best_word)
        candidates.remove(best_word)
        print("current_order:", current_order, best_score)
    print("-----貪欲法での挿入終了-----")
    
    best_score = scorer.get_perplexity([" ".join(current_order)], batch_size=1)[0]
    
    return current_order, best_score

# %%
def generate_neighbor(sequence, neighbor_type='swap'):
    """
    sequence: list of words
    neighbor_type: str, 近傍生成の種類 ('swap', 'insert', etc.)
    """
    new_seq = sequence[:]
    length = len(new_seq)

    if neighbor_type == 'swap':
        # ランダムに2つの位置を選んで入れ替える
        a, b = random.sample(range(length), 2)
        new_seq[a], new_seq[b] = new_seq[b], new_seq[a]

    elif neighbor_type == 'insert':
        # ある単語を抜き出し、別の位置に挿入する
        idx = random.randint(0, length - 1)
        word = new_seq.pop(idx)
        new_pos = random.randint(0, length - 1)
        new_seq.insert(new_pos, word)

    elif neighbor_type == 'shuffle_segment':
        # ランダムな部分区間を決めてシャッフル
        start = random.randint(0, length - 2)
        end = random.randint(start + 1, length - 1)
        segment = new_seq[start:end+1]
        random.shuffle(segment)
        new_seq[start:end+1] = segment

    elif neighbor_type == 'reverse_segment':
        # ランダムな部分区間を決めて反転
        start = random.randint(0, length - 2)
        end = random.randint(start + 1, length - 1)
        segment = new_seq[start:end+1]
        new_seq[start:end+1] = list(reversed(segment))

    # 他にも様々な近傍操作を追加可能

    return new_seq

# %%
def search_annealing(
    scorer,
    initial_sequence,
    temperature: float = 1.0,
    end_temperature: float = 0.01,
    cooling_rate: float = 0.999,
    iteration: int = 1000,
    batch_size: int = 10,
    neighbor_types: list = None
):
    """
    焼きなまし法による探索

    Parameters
    ----------
    CFG: 設定用（必要に応じて）
    scorer: perplexityを計算できるオブジェクト
    initial_sequence: 初期の単語リスト
    temperature: 開始時の温度
    cooling_rate: 温度の減少率
    iteration: 探索の反復回数
    batch_size: 1ステップで生成する近傍候補の数
    neighbor_types: 近傍生成の種類を指定するリスト
    """
    if neighbor_types is None:
        neighbor_types = ['swap', 'insert', 'shuffle_segment', 'reverse_segment']

    # 初期状態
    current_seq = initial_sequence[:]
    best_seq = current_seq[:]
    best_score = scorer.get_perplexity([" ".join(current_seq)], batch_size=1)[0]

    # current_scoreの計算
    current_score = best_score

    # スコア推移を記録するリスト
    scores_history = []
    temp_history = []
    
    # 現在の状態を持つリスト
    current_seqs = []
    current_scores = []
    
    # 初期解の生成
    for _ in range(CFG.batch_size):
        print("current_seq:", current_seq)
        print("current_score:", current_score)
        current_seq, current_score = shuffle_initialize(
            scorer,
            current_seq,
        )
        current_seqs.append(current_seq)
        current_scores.append(current_score)
        
    for itr in tqdm(range(iteration)):
        # 記録（ループの冒頭 or 最後のどちらでもOK）
        scores_history.append(current_scores[0])
        temp_history.append(temperature)
        
        # 近傍候補をまとめて生成
        neighbor_candidates = []
        for i in range(CFG.batch_size):
            # 近傍操作の種類をランダムに選ぶ
            n_type = random.choice(neighbor_types)
            neighbor_seq = generate_neighbor(current_seqs[i], n_type)
            neighbor_candidates.append(neighbor_seq)

        
        # まとめてスコアを計算（GPUを活用）
        texts = [" ".join(seq) for seq in neighbor_candidates]
        # print("texts:", texts)
        
        scores = scorer.get_perplexity(texts, batch_size=batch_size)
        # print("scores:", scores)
        
        # 候補の中から1つを焼きなまし法の確率的受容ルールで選ぶ
        for i, (cand_seq, cand_score) in enumerate(zip(neighbor_candidates, scores)):
            delta = cand_score - current_scores[i]
            accept_prob = math.exp(-delta / temperature) if delta > 0 else 1.0
                
            # スコアが良ければ必ず受容
            if (itr==0) or (random.random() < accept_prob):
                current_scores[i] = cand_score
                current_seqs[i] = cand_seq

        # ベストの更新
        # currnet_scoresのリストの最小値を取得
        if np.min(current_scores) < best_score:
            # current_scoresの最小値のインデックスを取得
            idx = np.argmin(current_scores)
            
            best_score = current_scores[idx]
            best_seq = current_seqs[idx]
            print(f"iter {itr}: best_score: {best_score}")
            print("best_seq:", best_seq)

        # 温度を下げる
        if itr % 10 == 0:
            temperature *= cooling_rate
        
        if itr % 1000 == 0:
            print(f"iter :{itr}, best_score: {best_score}, temperature: {temperature}")

            # current_seqsを結合して文字列保存
            current_seqs_text = [" ".join(seq) for seq in current_seqs]
            # current_seqsとcurrent_scoresのリストをdfとして保存
            df = pd.DataFrame(current_seqs_text)
            df["score"] = current_scores
            
            # indexとなっていたものをsequencre列に変更
            df = df.reset_index()
            df = df.rename(columns={"index": "sequence"})
            
            df.to_csv(f"{CFG.path}/out/current_texts.csv", index=False)
        if temperature < end_temperature:
            break
        
    return best_seq, best_score, scores_history, temp_history

# %%
def search_optimal_permutation(
    CFG,
    id: int, 
    scorer
):
    
    df = pd.read_csv(CFG.base_file_path)
    
    start = time.time()
    # 文字列を単語に分割
    words = df.loc[id,"text"].split()
    
    initial_sequence = words[:]
    print("--------初期配置の組み合わせ計算開始---------")
    initial_sequence, initial_score = shuffle_initialize(
        scorer=scorer,
        words=words
    )
    
    print(f"{id}th sample: {initial_sequence}")
    print(f"Elapsed time: {time.time() - start:.2f} sec")
    print(f"initial_score: {initial_score}")
    print("--------初期配置の組み合わせ計算終了---------")
    
    print("---------焼きなまし処理開始---------")
    best_sequence, best_score, scores_history, temp_history = search_annealing(
        scorer=scorer,
        initial_sequence=initial_sequence,
        temperature=CFG.temperature,
        end_temperature=CFG.end_temperature,
        cooling_rate=CFG.cooling_rate,
        iteration=CFG.iteration,
        batch_size=CFG.batch_size,
        neighbor_types=CFG.neighbor_types
    )
    print("---------焼きなまし処理終了---------")
    
    print(f"{id}th sample: {best_sequence}")
    print(f"Elapsed time: {time.time() - start:.2f} sec")
    print(f"best_score: {best_score}")
    
    plot_score_and_temperature(scores_history, temp_history)
    
    return best_sequence, best_score

# %%
# 文字列型にのみダブルクォーテーションを付ける関数
def add_quotes_to_strings(value):
    if isinstance(value, str):  # 文字列型の場合
        return f'"{value}"'
    return value  # それ以外はそのまま

# %%
# LOAD GEMMA SCORER
scorer = PerplexityCalculator(f'{CFG.path}/gemma_2_9b')
# Out:
# cuda
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
# scorer.clear_gpu_memory()

# %%
for i in [4]:
    
    print(f"Processing {i}th sample")
    best_sequence, best_score = search_optimal_permutation(
        CFG,
        id=i,
        scorer=scorer,
    )
    
    print("Best sequence:", best_sequence)
    print("Best score:", best_score)
    sub_df.loc[i, "best_value"] = best_score
    sub_df.loc[i, "text"] = " ".join(best_sequence)
# Out:
# Processing 4th sample
# --------初期配置の組み合わせ計算開始---------
# 4th sample: ['fireplace', 'fruitcake', 'night', 'wonder', 'as', 'toy', 'star', 'merry', 'to', 'you', 'season', 'angel', 'milk', 'wrapping', 'greeting', 'workshop', 'doll', 'hope', 'wreath', 'not', 'poinsettia', 'we', 'and', 'with', 'peace', 'believe', 'the', 'snowglobe', 'bow', 'chocolate', 'game', 'in', 'have', 'dream', 'candle', 'candy', 'card', 'that', 'eggnog', 'joy', 'puzzle', 'of', 'paper', 'peppermint', 'kaggle', 'hohoho', 'wish', 'cookie', 'it', 'from']
# Elapsed time: 0.88 sec
# initial_score: 2358.13186045924
# --------初期配置の組み合わせ計算終了---------
# ---------焼きなまし処理開始---------
# current_seq: ['fireplace', 'fruitcake', 'night', 'wonder', 'as', 'toy', 'star', 'merry', 'to', 'you', 'season', 'angel', 'milk', 'wrapping', 'greeting', 'workshop', 'doll', 'hope', 'wreath', 'not', 'poinsettia', 'we', 'and', 'with', 'peace', 'believe', 'the', 'snowglobe', 'bow', 'chocolate', 'game', 'in', 'have', 'dream', 'candle', 'candy', 'card', 'that', 'eggnog', 'joy', 'puzzle', 'of', 'paper', 'peppermint', 'kaggle', 'hohoho', 'wish', 'cookie', 'it', 'from']
# current_score: 2358.13186045924
# current_seq: ['wrapping', 'hope', 'fruitcake', 'angel', 'joy', 'merry', 'dream', 'card', 'to', 'candy', 'kaggle', 'milk', 'we', 'wreath', 'in', 'wish', 'candle', 'and', 'season', 'puzzle', 'toy', 'it', 'believe', 'that', 'snowglobe', 'night', 'workshop', 'from', 'the', 'game', 'cookie', 'poinsettia', 'with', 'as', 'you', 'greeting', 'chocolate', 'not', 'eggnog', 'star', 'bow', 'fireplace', 'have', 'peppermint', 'of', 'doll', 'paper', 'hohoho', 'peace', 'wonder']
# current_score: 1522.524360828172
# current_seq: ['bow', 'you', 'merry', 'wish', 'kaggle', 'wrapping', 'to', 'snowglobe', 'not', 'milk', 'that', 'greeting', 'peppermint', 'and', 'wreath', 'puzzle', 'hohoho', 'joy', 'star', 'night', 'as', 'have', 'we', 'peace', 'dream', 'cookie', 'doll', 'card', 'in', 'eggnog', 'candy', 'from', 'chocolate', 'fruitcake', 'angel', 'of', 'wonder', 'candle', 'the', 'fireplace', 'paper', 'hope', 'poinsettia', 'it', 'season', 'game', 'believe', 'workshop', 'toy', 'with']
# current_score: 1793.9721167586677
# current_seq: ['not', 'from', 'merry', 'workshop', 'cookie', 'greeting', 'fruitcake', 'wonder', 'in', 'milk', 'bow', 'game', 'of', 'dream', 'wish', 'as', 'puzzle', 'it', 'peace', 'paper', 'we', 'chocolate', 'and', 'card', 'believe', 'kaggle', 'hohoho', 'to', 'poinsettia', 'have', 'candle', 'that', 'eggnog', 'you', 'the', 'snowglobe', 'doll', 'joy', 'toy', 'night', 'wreath', 'wrapping', 'season', 'angel', 'candy', 'fireplace', 'hope', 'star', 'with', 'peppermint']
# current_score: 1970.2929179626208
# current_seq: ['star', 'with', 'candle', 'wreath', 'merry', 'have', 'as', 'fireplace', 'believe', 'wonder', 'wish', 'hohoho', 'eggnog', 'that', 'candy', 'to', 'in', 'you', 'workshop', 'not', 'wrapping', 'season', 'greeting', 'we', 'puzzle', 'bow', 'game', 'poinsettia', 'from', 'peppermint', 'and', 'toy', 'fruitcake', 'angel', 'snowglobe', 'card', 'peace', 'paper', 'it', 'joy', 'the', 'milk', 'night', 'chocolate', 'doll', 'hope', 'cookie', 'kaggle', 'of', 'dream']
# current_score: 1570.8544720412513
# current_seq: ['peppermint', 'believe', 'wrapping', 'star', 'angel', 'fruitcake', 'peace', 'night', 'hohoho', 'we', 'chocolate', 'wreath', 'you', 'wonder', 'milk', 'merry', 'from', 'paper', 'with', 'workshop', 'cookie', 'eggnog', 'puzzle', 'doll', 'greeting', 'hope', 'toy', 'in', 'season', 'game', 'to', 'wish', 'have', 'candle', 'it', 'kaggle', 'card', 'candy', 'bow', 'joy', 'that', 'and', 'poinsettia', 'not', 'of', 'snowglobe', 'as', 'fireplace', 'dream', 'the']
# current_score: 1528.4833526913917
# current_seq: ['wonder', 'merry', 'we', 'the', 'game', 'fruitcake', 'wish', 'season', 'not', 'angel', 'night', 'joy', 'paper', 'from', 'puzzle', 'you', 'chocolate', 'with', 'fireplace', 'to', 'kaggle', 'candle', 'doll', 'greeting', 'peppermint', 'snowglobe', 'star', 'hohoho', 'and', 'it', 'have', 'wrapping', 'of', 'poinsettia', 'bow', 'card', 'dream', 'toy', 'peace', 'believe', 'that', 'eggnog', 'wreath', 'milk', 'in', 'cookie', 'as', 'workshop', 'candy', 'hope']
# current_score: 1800.9935250997423
# current_seq: ['fireplace', 'wonder', 'merry', 'chocolate', 'fruitcake', 'wrapping', 'season', 'we', 'greeting', 'from', 'star', 'puzzle', 'wish', 'angel', 'kaggle', 'joy', 'game', 'hohoho', 'wreath', 'it', 'the', 'poinsettia', 'dream', 'have', 'paper', 'workshop', 'card', 'cookie', 'candy', 'not', 'night', 'snowglobe', 'eggnog', 'to', 'peppermint', 'hope', 'you', 'toy', 'peace', 'doll', 'bow', 'candle', 'as', 'in', 'with', 'believe', 'and', 'of', 'milk', 'that']
# current_score: 1639.8232653816679
# current_seq: ['bow', 'to', 'hope', 'we', 'paper', 'kaggle', 'wrapping', 'card', 'game', 'dream', 'fruitcake', 'wreath', 'toy', 'that', 'and', 'milk', 'star', 'angel', 'greeting', 'workshop', 'doll', 'peppermint', 'candy', 'candle', 'merry', 'from', 'of', 'it', 'have', 'chocolate', 'believe', 'as', 'puzzle', 'snowglobe', 'joy', 'fireplace', 'eggnog', 'in', 'with', 'season', 'hohoho', 'not', 'wonder', 'wish', 'poinsettia', 'peace', 'you', 'the', 'cookie', 'night']
# current_score: 1793.9721167586677
# current_seq: ['not', 'it', 'chocolate', 'that', 'doll', 'candy', 'hope', 'you', 'of', 'paper', 'night', 'dream', 'to', 'candle', 'eggnog', 'peppermint', 'merry', 'we', 'star', 'and', 'cookie', 'as', 'in', 'kaggle', 'believe', 'peace', 'have', 'the', 'poinsettia', 'from', 'with', 'milk', 'snowglobe', 'game', 'workshop', 'bow', 'wrapping', 'season', 'wish', 'fruitcake', 'angel', 'joy', 'puzzle', 'card', 'fireplace', 'greeting', 'toy', 'hohoho', 'wreath', 'wonder']
# current_score: 1424.703142573693
# current_seq: ['angel', 'game', 'kaggle', 'poinsettia', 'paper', 'peppermint', 'fruitcake', 'milk', 'we', 'season', 'cookie', 'it', 'the', 'star', 'eggnog', 'candle', 'and', 'believe', 'wish', 'night', 'hope', 'toy', 'doll', 'greeting', 'have', 'snowglobe', 'not', 'wonder', 'hohoho', 'wrapping', 'card', 'merry', 'from', 'that', 'you', 'dream', 'with', 'peace', 'fireplace', 'workshop', 'chocolate', 'of', 'wreath', 'bow', 'candy', 'puzzle', 'in', 'to', 'as', 'joy']
# current_score: 1786.9780822945145
# current_seq: ['merry', 'believe', 'wreath', 'night', 'workshop', 'with', 'angel', 'season', 'eggnog', 'snowglobe', 'from', 'it', 'greeting', 'fireplace', 'as', 'in', 'game', 'peppermint', 'and', 'to', 'paper', 'candy', 'milk', 'peace', 'the', 'that', 'hope', 'hohoho', 'you', 'kaggle', 'have', 'wrapping', 'fruitcake', 'poinsettia', 'chocolate', 'star', 'cookie', 'of', 'wish', 'dream', 'wonder', 'puzzle', 'doll', 'toy', 'card', 'bow', 'not', 'we', 'joy', 'candle']
# current_score: 1872.736951045589
# current_seq: ['night', 'the', 'toy', 'joy', 'not', 'with', 'star', 'chocolate', 'milk', 'wish', 'of', 'puzzle', 'eggnog', 'workshop', 'fireplace', 'have', 'merry', 'we', 'in', 'believe', 'bow', 'hope', 'candle', 'dream', 'hohoho', 'you', 'greeting', 'angel', 'poinsettia', 'as', 'wreath', 'season', 'snowglobe', 'wrapping', 'fruitcake', 'peace', 'peppermint', 'candy', 'cookie', 'it', 'game', 'kaggle', 'card', 'wonder', 'that', 'and', 'paper', 'to', 'from', 'doll']
# current_score: 1577.0026226114692
# current_seq: ['the', 'we', 'with', 'believe', 'joy', 'chocolate', 'cookie', 'fireplace', 'of', 'peppermint', 'milk', 'in', 'bow', 'candy', 'workshop', 'to', 'it', 'wish', 'dream', 'poinsettia', 'have', 'paper', 'snowglobe', 'merry', 'that', 'candle', 'wonder', 'you', 'kaggle', 'from', 'wrapping', 'star', 'not', 'game', 'hohoho', 'and', 'as', 'peace', 'angel', 'season', 'greeting', 'fruitcake', 'eggnog', 'hope', 'wreath', 'toy', 'doll', 'puzzle', 'card', 'night']
# current_score: 1614.4001620868264
# current_seq: ['fireplace', 'puzzle', 'of', 'candle', 'with', 'from', 'as', 'cookie', 'angel', 'dream', 'wreath', 'toy', 'that', 'candy', 'believe', 'greeting', 'you', 'and', 'not', 'to', 'poinsettia', 'card', 'wonder', 'hope', 'wish', 'in', 'hohoho', 'joy', 'eggnog', 'kaggle', 'merry', 'the', 'doll', 'game', 'night', 'snowglobe', 'we', 'fruitcake', 'chocolate', 'have', 'peppermint', 'bow', 'workshop', 'peace', 'star', 'milk', 'season', 'it', 'paper', 'wrapping']
# current_score: 1786.9780822945145
# current_seq: ['believe', 'of', 'with', 'that', 'candle', 'wrapping', 'and', 'wish', 'merry', 'eggnog', 'to', 'chocolate', 'hope', 'workshop', 'not', 'toy', 'poinsettia', 'you', 'have', 'wreath', 'peppermint', 'peace', 'as', 'we', 'cookie', 'card', 'hohoho', 'puzzle', 'star', 'it', 'fireplace', 'night', 'paper', 'candy', 'bow', 'milk', 'dream', 'wonder', 'in', 'fruitcake', 'joy', 'from', 'kaggle', 'greeting', 'the', 'doll', 'game', 'season', 'snowglobe', 'angel']
# current_score: 1962.6114738398403
# current_seq: ['not', 'with', 'greeting', 'game', 'fruitcake', 'puzzle', 'the', 'and', 'hohoho', 'dream', 'merry', 'wreath', 'paper', 'toy', 'star', 'night', 'believe', 'cookie', 'milk', 'peace', 'in', 'season', 'to', 'you', 'it', 'wonder', 'snowglobe', 'as', 'angel', 'bow', 'joy', 'have', 'card', 'chocolate', 'workshop', 'doll', 'peppermint', 'wish', 'wrapping', 'hope', 'candle', 'from', 'of', 'candy', 'that', 'we', 'poinsettia', 'eggnog', 'fireplace', 'kaggle']
# current_score: 1534.4656673893323
# current_seq: ['the', 'greeting', 'candy', 'chocolate', 'wish', 'candle', 'peace', 'snowglobe', 'poinsettia', 'puzzle', 'believe', 'in', 'we', 'you', 'doll', 'and', 'hope', 'of', 'toy', 'kaggle', 'joy', 'hohoho', 'merry', 'with', 'eggnog', 'to', 'have', 'that', 'wrapping', 'wreath', 'paper', 'dream', 'it', 'fireplace', 'as', 'season', 'bow', 'star', 'peppermint', 'angel', 'not', 'wonder', 'fruitcake', 'cookie', 'milk', 'from', 'card', 'game', 'workshop', 'night']
# current_score: 1745.582779603376
# current_seq: ['not', 'with', 'have', 'doll', 'to', 'candy', 'fireplace', 'card', 'peppermint', 'paper', 'and', 'snowglobe', 'game', 'that', 'wreath', 'in', 'it', 'hope', 'milk', 'puzzle', 'dream', 'kaggle', 'believe', 'greeting', 'wrapping', 'we', 'season', 'cookie', 'wish', 'poinsettia', 'merry', 'of', 'angel', 'from', 'the', 'candle', 'bow', 'star', 'toy', 'fruitcake', 'hohoho', 'workshop', 'you', 'peace', 'night', 'chocolate', 'as', 'wonder', 'eggnog', 'joy']
# current_score: 2480.973369853562
# current_seq: ['fruitcake', 'puzzle', 'merry', 'not', 'season', 'cookie', 'card', 'it', 'from', 'poinsettia', 'have', 'kaggle', 'eggnog', 'wrapping', 'you', 'joy', 'night', 'bow', 'and', 'chocolate', 'peppermint', 'toy', 'wreath', 'milk', 'fireplace', 'angel', 'game', 'paper', 'hope', 'candy', 'the', 'as', 'of', 'that', 'greeting', 'with', 'to', 'we', 'wonder', 'snowglobe', 'doll', 'in', 'workshop', 'candle', 'peace', 'dream', 'hohoho', 'believe', 'wish', 'star']
# current_score: 1408.1048482046956
# current_seq: ['bow', 'peace', 'of', 'dream', 'cookie', 'and', 'paper', 'peppermint', 'hohoho', 'have', 'milk', 'night', 'from', 'in', 'not', 'candle', 'chocolate', 'snowglobe', 'candy', 'joy', 'eggnog', 'it', 'that', 'the', 'believe', 'angel', 'with', 'to', 'as', 'kaggle', 'star', 'wrapping', 'game', 'puzzle', 'merry', 'doll', 'wreath', 'toy', 'wonder', 'card', 'we', 'hope', 'wish', 'season', 'greeting', 'you', 'poinsettia', 'fireplace', 'fruitcake', 'workshop']
# current_score: 1924.6511316769472
# current_seq: ['star', 'merry', 'with', 'joy', 'wreath', 'not', 'candy', 'the', 'believe', 'doll', 'hope', 'toy', 'have', 'cookie', 'game', 'card', 'poinsettia', 'paper', 'candle', 'eggnog', 'you', 'wish', 'chocolate', 'wonder', 'we', 'milk', 'and', 'peace', 'night', 'peppermint', 'season', 'that', 'dream', 'in', 'hohoho', 'of', 'greeting', 'to', 'wrapping', 'kaggle', 'it', 'puzzle', 'snowglobe', 'fireplace', 'fruitcake', 'as', 'workshop', 'angel', 'from', 'bow']
# current_score: 1745.582779603376
# current_seq: ['night', 'it', 'workshop', 'toy', 'fruitcake', 'as', 'poinsettia', 'of', 'chocolate', 'cookie', 'with', 'bow', 'puzzle', 'peace', 'candy', 'star', 'card', 'not', 'the', 'snowglobe', 'greeting', 'fireplace', 'hohoho', 'from', 'wreath', 'wrapping', 'candle', 'that', 'game', 'believe', 'joy', 'wish', 'hope', 'have', 'dream', 'milk', 'eggnog', 'in', 'peppermint', 'season', 'we', 'merry', 'to', 'and', 'kaggle', 'wonder', 'you', 'angel', 'paper', 'doll']
# current_score: 1939.7463575911895
# current_seq: ['puzzle', 'joy', 'chocolate', 'have', 'poinsettia', 'not', 'peace', 'doll', 'candy', 'hope', 'kaggle', 'in', 'fireplace', 'from', 'of', 'we', 'paper', 'milk', 'it', 'wonder', 'hohoho', 'night', 'fruitcake', 'snowglobe', 'as', 'believe', 'and', 'season', 'wreath', 'dream', 'that', 'eggnog', 'to', 'with', 'toy', 'card', 'angel', 'merry', 'the', 'greeting', 'peppermint', 'candle', 'workshop', 'you', 'bow', 'game', 'cookie', 'wrapping', 'wish', 'star']
# current_score: 2089.1890389111236
# current_seq: ['cookie', 'you', 'believe', 'snowglobe', 'wonder', 'game', 'as', 'star', 'card', 'poinsettia', 'we', 'joy', 'fruitcake', 'doll', 'hohoho', 'kaggle', 'peace', 'dream', 'bow', 'wish', 'workshop', 'greeting', 'it', 'candy', 'toy', 'peppermint', 'from', 'eggnog', 'season', 'night', 'angel', 'fireplace', 'with', 'have', 'candle', 'that', 'hope', 'of', 'puzzle', 'wrapping', 'not', 'merry', 'the', 'and', 'in', 'to', 'paper', 'chocolate', 'wreath', 'milk']
# current_score: 1780.0113149866502
# current_seq: ['fruitcake', 'from', 'you', 'hope', 'peppermint', 'paper', 'doll', 'wonder', 'joy', 'dream', 'that', 'wish', 'chocolate', 'snowglobe', 'card', 'workshop', 'bow', 'candy', 'wreath', 'of', 'night', 'greeting', 'season', 'angel', 'peace', 'cookie', 'hohoho', 'candle', 'poinsettia', 'eggnog', 'we', 'with', 'game', 'it', 'merry', 'the', 'star', 'believe', 'wrapping', 'as', 'to', 'in', 'puzzle', 'kaggle', 'fireplace', 'not', 'have', 'and', 'milk', 'toy']
# current_score: 1452.8028942027192
# current_seq: ['paper', 'candle', 'poinsettia', 'toy', 'puzzle', 'to', 'merry', 'the', 'greeting', 'have', 'believe', 'wrapping', 'that', 'peppermint', 'candy', 'kaggle', 'hohoho', 'as', 'fireplace', 'angel', 'dream', 'we', 'season', 'star', 'doll', 'cookie', 'game', 'of', 'and', 'fruitcake', 'hope', 'eggnog', 'it', 'workshop', 'peace', 'in', 'milk', 'with', 'wish', 'you', 'not', 'chocolate', 'snowglobe', 'night', 'wreath', 'from', 'wonder', 'joy', 'bow', 'card']
# current_score: 2017.01706801857
# current_seq: ['have', 'wrapping', 'as', 'toy', 'star', 'workshop', 'puzzle', 'greeting', 'and', 'kaggle', 'poinsettia', 'snowglobe', 'bow', 'in', 'fruitcake', 'it', 'merry', 'we', 'not', 'the', 'cookie', 'you', 'joy', 'hope', 'wreath', 'candy', 'chocolate', 'season', 'doll', 'game', 'that', 'wonder', 'fireplace', 'dream', 'believe', 'with', 'card', 'peppermint', 'wish', 'from', 'candle', 'eggnog', 'to', 'paper', 'of', 'peace', 'angel', 'milk', 'hohoho', 'night']
# current_score: 2122.088979078394
# current_seq: ['of', 'you', 'night', 'kaggle', 'star', 'joy', 'believe', 'we', 'milk', 'paper', 'wish', 'hohoho', 'angel', 'workshop', 'eggnog', 'candy', 'that', 'as', 'and', 'puzzle', 'fireplace', 'season', 'chocolate', 'game', 'peppermint', 'fruitcake', 'poinsettia', 'cookie', 'dream', 'the', 'greeting', 'with', 'in', 'card', 'hope', 'wrapping', 'wreath', 'snowglobe', 'from', 'it', 'merry', 'have', 'bow', 'to', 'candle', 'doll', 'peace', 'wonder', 'toy', 'not']
# current_score: 2348.938375594565
# current_seq: ['cookie', 'you', 'dream', 'peace', 'that', 'workshop', 'poinsettia', 'hohoho', 'and', 'merry', 'puzzle', 'greeting', 'night', 'it', 'believe', 'hope', 'toy', 'season', 'wonder', 'joy', 'wreath', 'peppermint', 'snowglobe', 'wish', 'not', 'paper', 'have', 'candle', 'milk', 'of', 'angel', 'bow', 'card', 'the', 'with', 'from', 'we', 'candy', 'fireplace', 'doll', 'kaggle', 'as', 'wrapping', 'chocolate', 'eggnog', 'star', 'in', 'fruitcake', 'game', 'to']
# current_score: 2223.930155552819
# current_seq: ['to', 'cookie', 'greeting', 'doll', 'peace', 'fruitcake', 'poinsettia', 'the', 'hohoho', 'workshop', 'fireplace', 'you', 'wish', 'that', 'dream', 'season', 'peppermint', 'from', 'not', 'believe', 'have', 'bow', 'kaggle', 'card', 'star', 'wreath', 'snowglobe', 'toy', 'and', 'wrapping', 'of', 'eggnog', 'merry', 'hope', 'it', 'candle', 'puzzle', 'angel', 'candy', 'night', 'joy', 'milk', 'with', 'wonder', 'paper', 'as', 'chocolate', 'game', 'in', 'we']
# current_score: 1970.2929179626208
# current_seq: ['candy', 'greeting', 'workshop', 'kaggle', 'have', 'merry', 'believe', 'it', 'hohoho', 'to', 'toy', 'you', 'night', 'bow', 'chocolate', 'joy', 'peppermint', 'fireplace', 'not', 'and', 'with', 'we', 'wish', 'snowglobe', 'in', 'as', 'puzzle', 'star', 'dream', 'the', 'season', 'fruitcake', 'eggnog', 'doll', 'of', 'wrapping', 'cookie', 'poinsettia', 'from', 'angel', 'wonder', 'that', 'candle', 'wreath', 'milk', 'peace', 'card', 'hope', 'paper', 'game']
# current_score: 1659.1529831272167
#   0%|          | 0/10000000 [00:00<?, ?it/s]
# iter 0: best_score: 1659.1529831272167
# best_seq: ['wrapping', 'bow', 'of', 'merry', 'game', 'poinsettia', 'you', 'have', 'candy', 'we', 'puzzle', 'eggnog', 'toy', 'hope', 'peppermint', 'cookie', 'chocolate', 'as', 'and', 'wreath', 'wish', 'wonder', 'joy', 'with', 'that', 'fireplace', 'fruitcake', 'candle', 'angel', 'to', 'doll', 'kaggle', 'hohoho', 'milk', 'season', 'dream', 'snowglobe', 'the', 'paper', 'from', 'night', 'workshop', 'believe', 'greeting', 'card', 'not', 'star', 'in', 'it', 'peace']
# iter :0, best_score: 1659.1529831272167, temperature: 99.99
# iter 3: best_score: 1528.4833526913917
# best_seq: ['wrapping', 'bow', 'of', 'merry', 'game', 'poinsettia', 'you', 'have', 'candy', 'peppermint', 'puzzle', 'eggnog', 'toy', 'hope', 'we', 'cookie', 'chocolate', 'as', 'and', 'wreath', 'wish', 'wonder', 'joy', 'with', 'angel', 'fireplace', 'fruitcake', 'candle', 'that', 'to', 'doll', 'kaggle', 'hohoho', 'milk', 'season', 'dream', 'snowglobe', 'the', 'paper', 'from', 'night', 'workshop', 'believe', 'greeting', 'card', 'not', 'star', 'in', 'it', 'peace']
# iter 13: best_score: 1402.6151676542092
# best_seq: ['wrapping', 'bow', 'of', 'merry', 'game', 'poinsettia', 'you', 'have', 'workshop', 'puzzle', 'eggnog', 'toy', 'hope', 'we', 'cookie', 'chocolate', 'as', 'and', 'wreath', 'wish', 'wonder', 'joy', 'with', 'angel', 'fireplace', 'fruitcake', 'candle', 'that', 'peppermint', 'to', 'doll', 'kaggle', 'hohoho', 'milk', 'season', 'dream', 'snowglobe', 'the', 'paper', 'from', 'night', 'candy', 'believe', 'greeting', 'card', 'not', 'star', 'in', 'it', 'peace']
# iter 17: best_score: 1354.1611985934896
# best_seq: ['in', 'bow', 'of', 'merry', 'game', 'poinsettia', 'you', 'we', 'puzzle', 'eggnog', 'toy', 'doll', 'peppermint', 'cookie', 'chocolate', 'wrapping', 'believe', 'wreath', 'wish', 'wonder', 'joy', 'with', 'that', 'fruitcake', 'candle', 'angel', 'to', 'hope', 'kaggle', 'hohoho', 'candy', 'milk', 'and', 'dream', 'snowglobe', 'the', 'paper', 'from', 'season', 'night', 'fireplace', 'have', 'workshop', 'greeting', 'card', 'not', 'star', 'as', 'it', 'peace']
# iter 26: best_score: 1272.1167191138777
# best_seq: ['wrapping', 'bow', 'of', 'merry', 'game', 'poinsettia', 'you', 'have', 'workshop', 'not', 'eggnog', 'toy', 'hope', 'we', 'cookie', 'chocolate', 'doll', 'and', 'wreath', 'wish', 'wonder', 'joy', 'angel', 'fireplace', 'fruitcake', 'candle', 'that', 'peppermint', 'to', 'as', 'kaggle', 'hohoho', 'milk', 'season', 'dream', 'with', 'snowglobe', 'the', 'paper', 'from', 'night', 'candy', 'believe', 'greeting', 'card', 'puzzle', 'star', 'in', 'it', 'peace']
# iter 32: best_score: 1204.4159022708138
# best_seq: ['wrapping', 'bow', 'of', 'wish', 'game', 'poinsettia', 'you', 'have', 'workshop', 'not', 'eggnog', 'toy', 'hope', 'we', 'cookie', 'chocolate', 'doll', 'and', 'wreath', 'merry', 'wonder', 'joy', 'angel', 'fireplace', 'fruitcake', 'candle', 'that', 'peppermint', 'to', 'as', 'kaggle', 'hohoho', 'milk', 'season', 'dream', 'with', 'snowglobe', 'the', 'paper', 'from', 'night', 'candy', 'believe', 'greeting', 'card', 'puzzle', 'star', 'in', 'it', 'peace']
# iter 33: best_score: 1092.357790916928
# best_seq: ['puzzle', 'bow', 'of', 'merry', 'workshop', 'paper', 'you', 'have', 'candy', 'we', 'as', 'eggnog', 'toy', 'chocolate', 'peppermint', 'snowglobe', 'greeting', 'cookie', 'game', 'wrapping', 'and', 'joy', 'that', 'fruitcake', 'wish', 'candle', 'poinsettia', 'angel', 'to', 'doll', 'kaggle', 'hohoho', 'milk', 'season', 'wonder', 'with', 'the', 'hope', 'from', 'night', 'dream', 'believe', 'wreath', 'it', 'not', 'star', 'fireplace', 'in', 'card', 'peace']
# iter 35: best_score: 1050.510221115274
# best_seq: ['puzzle', 'bow', 'of', 'merry', 'workshop', 'paper', 'you', 'have', 'candy', 'we', 'as', 'toy', 'chocolate', 'peppermint', 'snowglobe', 'greeting', 'cookie', 'game', 'eggnog', 'wrapping', 'and', 'joy', 'that', 'fruitcake', 'wish', 'candle', 'poinsettia', 'angel', 'to', 'doll', 'kaggle', 'hohoho', 'milk', 'season', 'wonder', 'with', 'the', 'hope', 'from', 'night', 'dream', 'believe', 'wreath', 'it', 'not', 'star', 'fireplace', 'in', 'card', 'peace']
# iter 43: best_score: 998.495853382024
# best_seq: ['puzzle', 'fireplace', 'bow', 'doll', 'workshop', 'merry', 'paper', 'you', 'have', 'candy', 'we', 'as', 'toy', 'chocolate', 'peppermint', 'snowglobe', 'greeting', 'cookie', 'game', 'eggnog', 'wrapping', 'and', 'that', 'fruitcake', 'wish', 'candle', 'poinsettia', 'angel', 'to', 'of', 'kaggle', 'hohoho', 'milk', 'season', 'wonder', 'with', 'the', 'hope', 'from', 'night', 'dream', 'believe', 'joy', 'it', 'not', 'star', 'in', 'wreath', 'card', 'peace']
# iter 114: best_score: 967.7753655846766
# best_seq: ['fireplace', 'toy', 'of', 'to', 'game', 'night', 'it', 'merry', 'you', 'season', 'we', 'wonder', 'candy', 'wish', 'chocolate', 'fruitcake', 'from', 'peppermint', 'dream', 'not', 'and', 'hope', 'poinsettia', 'wrapping', 'that', 'wreath', 'angel', 'puzzle', 'doll', 'eggnog', 'bow', 'candle', 'peace', 'kaggle', 'milk', 'card', 'have', 'greeting', 'snowglobe', 'paper', 'workshop', 'as', 'with', 'the', 'joy', 'believe', 'in', 'star', 'cookie', 'hohoho']
# iter 115: best_score: 941.6712762187423
# best_seq: ['fireplace', 'toy', 'of', 'to', 'game', 'night', 'it', 'merry', 'you', 'season', 'we', 'wonder', 'candy', 'wish', 'chocolate', 'fruitcake', 'from', 'peppermint', 'dream', 'not', 'and', 'hope', 'poinsettia', 'wrapping', 'that', 'wreath', 'angel', 'puzzle', 'doll', 'eggnog', 'bow', 'candle', 'peace', 'kaggle', 'milk', 'card', 'have', 'greeting', 'paper', 'workshop', 'as', 'with', 'the', 'joy', 'believe', 'in', 'star', 'cookie', 'snowglobe', 'hohoho']
# iter 224: best_score: 923.4577050016666
# best_seq: ['peppermint', 'in', 'candy', 'hohoho', 'as', 'greeting', 'with', 'have', 'we', 'believe', 'peace', 'milk', 'eggnog', 'joy', 'doll', 'from', 'toy', 'workshop', 'game', 'night', 'cookie', 'wish', 'wonder', 'star', 'puzzle', 'chocolate', 'wrapping', 'snowglobe', 'fireplace', 'wreath', 'poinsettia', 'that', 'hope', 'merry', 'angel', 'it', 'to', 'fruitcake', 'kaggle', 'season', 'paper', 'and', 'dream', 'of', 'you', 'not', 'the', 'card', 'bow', 'candle']
# iter 281: best_score: 905.5964161413509
# best_seq: ['greeting', 'snowglobe', 'wonder', 'workshop', 'puzzle', 'fruitcake', 'game', 'and', 'it', 'chocolate', 'peace', 'milk', 'wish', 'night', 'joy', 'eggnog', 'peppermint', 'kaggle', 'that', 'cookie', 'with', 'candle', 'dream', 'the', 'from', 'star', 'hope', 'we', 'angel', 'have', 'wrapping', 'merry', 'you', 'not', 'to', 'as', 'believe', 'hohoho', 'paper', 'of', 'toy', 'doll', 'wreath', 'in', 'bow', 'candy', 'fireplace', 'card', 'poinsettia', 'season']
# iter 292: best_score: 898.5490089196367
# best_seq: ['greeting', 'snowglobe', 'wonder', 'workshop', 'puzzle', 'fruitcake', 'game', 'candy', 'and', 'it', 'chocolate', 'peace', 'milk', 'peppermint', 'eggnog', 'night', 'joy', 'wish', 'kaggle', 'that', 'cookie', 'with', 'candle', 'dream', 'the', 'from', 'star', 'hope', 'we', 'angel', 'have', 'wrapping', 'merry', 'you', 'not', 'to', 'as', 'believe', 'hohoho', 'paper', 'of', 'toy', 'doll', 'wreath', 'card', 'in', 'bow', 'fireplace', 'poinsettia', 'season']
# iter 302: best_score: 881.1694978531985
# best_seq: ['wish', 'have', 'joy', 'workshop', 'puzzle', 'wonder', 'you', 'hope', 'merry', 'night', 'and', 'we', 'chocolate', 'candle', 'dream', 'with', 'doll', 'greeting', 'card', 'cookie', 'angel', 'toy', 'the', 'not', 'paper', 'milk', 'poinsettia', 'that', 'it', 'fruitcake', 'fireplace', 'of', 'game', 'candy', 'peppermint', 'kaggle', 'from', 'season', 'in', 'eggnog', 'as', 'wrapping', 'snowglobe', 'bow', 'believe', 'wreath', 'to', 'hohoho', 'star', 'peace']
# iter 414: best_score: 877.7341435468668
# best_seq: ['snowglobe', 'night', 'star', 'milk', 'candle', 'dream', 'and', 'believe', 'kaggle', 'in', 'toy', 'puzzle', 'workshop', 'bow', 'that', 'it', 'doll', 'wish', 'season', 'not', 'candy', 'peppermint', 'as', 'hohoho', 'chocolate', 'fruitcake', 'wonder', 'fireplace', 'from', 'poinsettia', 'wrapping', 'paper', 'angel', 'we', 'of', 'eggnog', 'hope', 'to', 'cookie', 'the', 'have', 'wreath', 'peace', 'with', 'game', 'you', 'greeting', 'merry', 'card', 'joy']
# iter 529: best_score: 857.401454011125
# best_seq: ['snowglobe', 'wish', 'paper', 'eggnog', 'angel', 'dream', 'wrapping', 'merry', 'game', 'toy', 'to', 'from', 'season', 'the', 'we', 'believe', 'doll', 'bow', 'chocolate', 'greeting', 'card', 'fruitcake', 'that', 'hohoho', 'wreath', 'it', 'kaggle', 'puzzle', 'candy', 'peppermint', 'of', 'wonder', 'star', 'in', 'and', 'not', 'cookie', 'candle', 'workshop', 'fireplace', 'you', 'with', 'peace', 'joy', 'poinsettia', 'hope', 'have', 'as', 'night', 'milk']
# iter 543: best_score: 818.1381828290899
# best_seq: ['snowglobe', 'wish', 'paper', 'eggnog', 'angel', 'dream', 'candy', 'wrapping', 'merry', 'game', 'peppermint', 'to', 'from', 'season', 'we', 'believe', 'doll', 'bow', 'chocolate', 'greeting', 'card', 'fruitcake', 'the', 'that', 'hohoho', 'wreath', 'it', 'kaggle', 'puzzle', 'toy', 'of', 'wonder', 'star', 'in', 'and', 'not', 'cookie', 'candle', 'workshop', 'fireplace', 'you', 'with', 'peace', 'joy', 'poinsettia', 'hope', 'have', 'as', 'night', 'milk']
# iter 599: best_score: 808.6065842894934
# best_seq: ['wreath', 'toy', 'you', 'with', 'fruitcake', 'greeting', 'the', 'not', 'candy', 'fireplace', 'night', 'milk', 'in', 'that', 'as', 'star', 'from', 'eggnog', 'game', 'puzzle', 'hohoho', 'season', 'wrapping', 'paper', 'wish', 'have', 'hope', 'to', 'and', 'joy', 'candle', 'card', 'it', 'we', 'poinsettia', 'merry', 'chocolate', 'peace', 'kaggle', 'bow', 'wonder', 'dream', 'snowglobe', 'doll', 'workshop', 'of', 'angel', 'cookie', 'peppermint', 'believe']
# iter :1000, best_score: 808.6065842894934, temperature: 98.99503337575031
# iter 1208: best_score: 802.313957927379
# best_seq: ['peppermint', 'joy', 'toy', 'dream', 'doll', 'paper', 'workshop', 'bow', 'wonder', 'fruitcake', 'angel', 'we', 'hope', 'game', 'peace', 'wrapping', 'card', 'not', 'candy', 'merry', 'the', 'poinsettia', 'in', 'that', 'believe', 'eggnog', 'greeting', 'kaggle', 'milk', 'as', 'to', 'season', 'cookie', 'puzzle', 'and', 'from', 'it', 'have', 'wish', 'wreath', 'fireplace', 'night', 'chocolate', 'snowglobe', 'you', 'star', 'of', 'with', 'candle', 'hohoho']
# iter 1215: best_score: 799.1860322364524
# best_seq: ['peppermint', 'joy', 'toy', 'dream', 'doll', 'paper', 'workshop', 'bow', 'wonder', 'fruitcake', 'angel', 'we', 'hope', 'game', 'peace', 'with', 'wrapping', 'card', 'not', 'candy', 'merry', 'the', 'poinsettia', 'in', 'that', 'believe', 'eggnog', 'greeting', 'kaggle', 'milk', 'as', 'to', 'season', 'cookie', 'puzzle', 'and', 'from', 'it', 'have', 'wish', 'wreath', 'fireplace', 'night', 'chocolate', 'snowglobe', 'you', 'star', 'of', 'candle', 'hohoho']
# iter :2000, best_score: 799.1860322364524, temperature: 98.00996732739186
# iter 2276: best_score: 789.8752329392117
# best_seq: ['wreath', 'bow', 'wonder', 'toy', 'joy', 'milk', 'candle', 'angel', 'chocolate', 'greeting', 'star', 'cookie', 'doll', 'kaggle', 'poinsettia', 'wish', 'game', 'of', 'hope', 'believe', 'puzzle', 'hohoho', 'night', 'eggnog', 'wrapping', 'to', 'and', 'that', 'workshop', 'not', 'it', 'the', 'have', 'snowglobe', 'you', 'fruitcake', 'paper', 'season', 'from', 'we', 'as', 'candy', 'peppermint', 'in', 'with', 'card', 'peace', 'fireplace', 'dream', 'merry']
# iter :3000, best_score: 789.8752329392117, temperature: 97.03470333764717
# iter 3038: best_score: 780.6729077394361
# best_seq: ['wreath', 'believe', 'game', 'wish', 'as', 'candle', 'merry', 'greeting', 'milk', 'kaggle', 'have', 'season', 'it', 'not', 'to', 'you', 'night', 'card', 'hope', 'that', 'hohoho', 'doll', 'angel', 'with', 'peace', 'we', 'dream', 'in', 'candy', 'joy', 'wrapping', 'chocolate', 'puzzle', 'eggnog', 'snowglobe', 'and', 'workshop', 'paper', 'poinsettia', 'of', 'cookie', 'from', 'fruitcake', 'the', 'fireplace', 'star', 'peppermint', 'bow', 'toy', 'wonder']
# iter 3039: best_score: 768.5696961361268
# best_seq: ['wreath', 'believe', 'game', 'wish', 'as', 'candle', 'merry', 'greeting', 'milk', 'kaggle', 'have', 'season', 'it', 'not', 'to', 'you', 'night', 'card', 'hope', 'that', 'hohoho', 'doll', 'angel', 'with', 'peace', 'we', 'dream', 'in', 'candy', 'joy', 'wrapping', 'chocolate', 'puzzle', 'eggnog', 'and', 'workshop', 'paper', 'poinsettia', 'of', 'cookie', 'from', 'fruitcake', 'the', 'snowglobe', 'fireplace', 'star', 'peppermint', 'bow', 'toy', 'wonder']
# iter 3045: best_score: 759.615587958536
# best_seq: ['wreath', 'believe', 'game', 'wish', 'as', 'candle', 'merry', 'greeting', 'milk', 'kaggle', 'have', 'season', 'it', 'not', 'to', 'you', 'night', 'card', 'hope', 'that', 'hohoho', 'doll', 'angel', 'with', 'peace', 'chocolate', 'we', 'dream', 'in', 'candy', 'joy', 'wrapping', 'puzzle', 'eggnog', 'and', 'workshop', 'paper', 'poinsettia', 'of', 'cookie', 'from', 'fruitcake', 'the', 'snowglobe', 'fireplace', 'star', 'peppermint', 'bow', 'toy', 'wonder']
# iter 3438: best_score: 699.7906717746478
# best_seq: ['wreath', 'believe', 'dream', 'not', 'of', 'workshop', 'night', 'wish', 'with', 'fireplace', 'joy', 'you', 'as', 'fruitcake', 'have', 'we', 'card', 'greeting', 'candle', 'kaggle', 'the', 'that', 'poinsettia', 'it', 'peace', 'chocolate', 'in', 'star', 'wrapping', 'and', 'paper', 'merry', 'wonder', 'candy', 'hope', 'milk', 'cookie', 'game', 'from', 'puzzle', 'eggnog', 'angel', 'toy', 'peppermint', 'bow', 'to', 'season', 'snowglobe', 'doll', 'hohoho']
# iter 3441: best_score: 697.0624464971402
# best_seq: ['wreath', 'believe', 'dream', 'not', 'of', 'workshop', 'night', 'wish', 'with', 'fireplace', 'joy', 'you', 'as', 'fruitcake', 'have', 'we', 'poinsettia', 'greeting', 'candle', 'kaggle', 'the', 'that', 'card', 'it', 'peace', 'chocolate', 'in', 'star', 'wrapping', 'and', 'paper', 'merry', 'wonder', 'candy', 'hope', 'milk', 'cookie', 'game', 'from', 'puzzle', 'eggnog', 'angel', 'toy', 'peppermint', 'bow', 'to', 'season', 'snowglobe', 'doll', 'hohoho']
# iter :4000, best_score: 697.0624464971402, temperature: 96.06914386955107
# iter :5000, best_score: 697.0624464971402, temperature: 95.11319235669531
# iter :6000, best_score: 697.0624464971402, temperature: 94.16675319357148
# iter :7000, best_score: 697.0624464971402, temperature: 93.22973172600908
# iter :8000, best_score: 697.0624464971402, temperature: 92.3020342417093
# iter :9000, best_score: 697.0624464971402, temperature: 91.38356796087267
# iter :10000, best_score: 697.0624464971402, temperature: 90.47424102692001

# %%
sub_df

# %%
# 各セルに関数を適用
sub_df["text"] = sub_df["text"].astype(str)
sub_df = sub_df.applymap(add_quotes_to_strings)

# %%
sub_df[["id", "text"]].to_csv(f"{CFG.path}/out/submission_{ex_num}.csv", index=False, header=True, quoting=csv.QUOTE_NONE)
sub_df.to_csv(f"{CFG.path}/out/score_{ex_num}.csv", index=False, header=True, quoting=csv.QUOTE_NONE)

# %%
np.mean(sub_df["best_value"])
