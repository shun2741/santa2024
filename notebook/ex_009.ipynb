# %% [markdown]
# ### SAのテンプレート
# バッチサイズ分だけ並行して実施する

# %%
ex_num = "009"

# %%
import os
# 環境によって変更
# os.chdir('/home/jovyan/work/notebook')

# %%
class CFG:
    # path = "../model"    
    path = "../../output"
    base_file_path = "../input/sub20241221.csv"
    
    # 焼きなましのパラメータ
    temperature=100
    end_temperature=1.0
    cooling_rate=0.9999
    iteration=int(1e6)
    batch_size=32
    neighbor_types = ["swap", "insert", "inverse", "slide"]

# %%
import numpy as np
import pandas as pd
import os
import time
import csv

from tqdm.notebook import tqdm

import random
from typing import List, Callable
import itertools, math
from typing import List, Tuple

from utils import PerplexityCalculator
# 可視化用
import matplotlib.pyplot as plt

# %% [markdown]
# ### データ読み込み

# %%
df = pd.read_csv(CFG.base_file_path)

# %%
sub_df = df.copy()
sub_df["best_value"] = 0

# %%
df
# Out:
#    id                                               text
# 0   0  reindeer mistletoe elf gingerbread family adve...
# 1   1  reindeer sleep walk the night and drive mistle...
# 2   2  jingle yuletide carol cheer holly stocking chi...
# 3   3  sleigh the holly jingle unwrap gifts of magi r...
# 4   4  peppermint candy milk chocolate eggnog fruitca...
# 5   5  poinsettia yuletide eggnog fruitcake gingerbre...

# %% [markdown]
# ### 関数

# %%
def plot_score_and_temperature(scores_history, temp_history):
    # x 軸: イテレーション
    x = range(len(scores_history))
    
    # Figure と Axes を作成
    fig, ax1 = plt.subplots(figsize=(8,5))
    
    # スコア用の軸 (左)
    color_score = 'tab:blue'
    ax1.set_xlabel('Iteration')
    ax1.set_ylabel('Score (Perplexity)', color=color_score)
    ax1.plot(x, scores_history, label='Score', color=color_score)
    ax1.tick_params(axis='y', labelcolor=color_score)
    
    # 温度用の軸 (右) : twinx で第二のY軸を作成
    ax2 = ax1.twinx()
    color_temp = 'tab:red'
    ax2.set_ylabel('Temperature', color=color_temp)
    ax2.plot(x, temp_history, label='Temperature', color=color_temp)
    ax2.tick_params(axis='y', labelcolor=color_temp)
    
    # タイトル等
    plt.title('Score & Temperature Transition')
    fig.tight_layout()
    plt.show()

# %%
# 2単語組み合わせ全てから最低スコアとなるペアを探す
def find_initial_pair(
    CFG,
    scorer,
    words
):
    best_score = float('inf')
    best_pair = None
    for i in range(len(words)):
        perms = []
        for j in range(i+1, len(words)):
            pair = [words[i], words[j]]
            perms.append(" ".join(pair))
        
        scores = scorer.get_perplexity(perms, batch_size=CFG.batch_size)
        for j, perm in enumerate(perms):
            if scores[j] < best_score:
                best_score = scores[j]
                best_pair = perm.split(" ")
                
                # print(f"best_score: {best_score}, best_pair: {best_pair}")
     
    return best_pair, best_score

# %%
# 文字の順番をランダムにして、返す
def shuffle_initialize(
    scorer,
    words
):
    random.shuffle(words)
    return words, scorer.get_perplexity([" ".join(words)], batch_size=1)[0]

# %%
# 文字列のファイルからコストを最小化する文字列を生成する
def greedy_add_initialize(
    CFG,
    scorer,
    initial_words: list
):
    
    # 全単語
    candidates = initial_words[:]

    print("candidates:", candidates)
    print("-----初期配置の組み合わせ計算開始-----")
    # 初期配置を求める
    initial, initial_score = find_initial_pair(
        CFG,
        scorer,
        candidates
    )
    print("-----初期配置の組み合わせ計算終了-----")
    for w in initial:
        candidates.remove(w)

    print("initial:", initial, initial_score)
    current_order = initial[:]

    print("-----貪欲法での挿入開始-----")
    # 貪欲に残りを挿入
    while candidates:
        best_score = float('inf')
        best_word = None
        best_pos = None

        # 残っている単語それぞれについて
        for w in candidates:
            # current_orderのあらゆる挿入位置を試す
            # 挿入位置は0からlen(current_order)まで
            
            perms = []
            for pos in range(len(current_order) + 1):
                new_order = current_order[:pos] + [w] + current_order[pos:]
                perms.append(" ".join(new_order))
                
            scores = scorer.get_perplexity(perms, batch_size=CFG.BATCH_SIZE)
                
            for pos in range(len(current_order) + 1):
                if scores[pos] < best_score:
                    best_score = scores[pos]
                    best_word = w
                    best_pos = pos
                    
                    # print("best_word:", best_word, best_score)
        
        # best_wordをbest_posに挿入
        current_order.insert(best_pos, best_word)
        candidates.remove(best_word)
        print("current_order:", current_order, best_score)
    print("-----貪欲法での挿入終了-----")
    
    best_score = scorer.get_perplexity([" ".join(current_order)], batch_size=1)[0]
    
    return current_order, best_score

# %%
def generate_neighbor(sequence, neighbor_type='swap'):
    """
    sequence: list of words
    neighbor_type: str, 近傍生成の種類 ('swap', 'insert', etc.)
    """
    new_seq = sequence[:]
    length = len(new_seq)

    if neighbor_type == 'swap':
        # ランダムに2つの位置を選んで入れ替える
        a, b = random.sample(range(length), 2)
        new_seq[a], new_seq[b] = new_seq[b], new_seq[a]

    elif neighbor_type == 'insert':
        # ある単語を抜き出し、別の位置に挿入する
        idx = random.randint(0, length - 1)
        word = new_seq.pop(idx)
        new_pos = random.randint(0, length - 1)
        new_seq.insert(new_pos, word)

    elif neighbor_type == 'shuffle_segment':
        # ランダムな部分区間を決めてシャッフル
        start = random.randint(0, length - 2)
        end = random.randint(start + 1, length - 1)
        segment = new_seq[start:end+1]
        random.shuffle(segment)
        new_seq[start:end+1] = segment

    elif neighbor_type == 'reverse_segment':
        # ランダムな部分区間を決めて反転
        start = random.randint(0, length - 2)
        end = random.randint(start + 1, length - 1)
        segment = new_seq[start:end+1]
        new_seq[start:end+1] = list(reversed(segment))

    # 他にも様々な近傍操作を追加可能

    return new_seq

# %%
def search_annealing(
    scorer,
    initial_sequence,
    temperature: float = 1.0,
    end_temperature: float = 0.01,
    cooling_rate: float = 0.999,
    iteration: int = 1000,
    batch_size: int = 10,
    neighbor_types: list = None
):
    """
    焼きなまし法による探索

    Parameters
    ----------
    CFG: 設定用（必要に応じて）
    scorer: perplexityを計算できるオブジェクト
    initial_sequence: 初期の単語リスト
    temperature: 開始時の温度
    cooling_rate: 温度の減少率
    iteration: 探索の反復回数
    batch_size: 1ステップで生成する近傍候補の数
    neighbor_types: 近傍生成の種類を指定するリスト
    """
    if neighbor_types is None:
        neighbor_types = ['swap', 'insert', 'shuffle_segment', 'reverse_segment']

    # 初期状態
    current_seq = initial_sequence[:]
    best_seq = current_seq[:]
    best_score = scorer.get_perplexity([" ".join(current_seq)], batch_size=1)[0]

    # current_scoreの計算
    current_score = best_score

    # スコア推移を記録するリスト
    scores_history = []
    temp_history = []
    
    # 現在の状態を持つリスト
    current_seqs = []
    current_scores = []
    
    # 初期解の生成
    for _ in range(CFG.batch_size):
        print("current_seq:", current_seq)
        print("current_score:", current_score)
        current_seq, current_score = shuffle_initialize(
            scorer,
            current_seq,
        )
        current_seqs.append(current_seq)
        current_scores.append(current_score)
        
    for itr in tqdm(range(iteration)):
        # 記録（ループの冒頭 or 最後のどちらでもOK）
        scores_history.append(current_scores[0])
        temp_history.append(temperature)
        
        # 近傍候補をまとめて生成
        neighbor_candidates = []
        for i in range(CFG.batch_size):
            # 近傍操作の種類をランダムに選ぶ
            n_type = random.choice(neighbor_types)
            neighbor_seq = generate_neighbor(current_seqs[i], n_type)
            neighbor_candidates.append(neighbor_seq)

        
        # まとめてスコアを計算（GPUを活用）
        texts = [" ".join(seq) for seq in neighbor_candidates]
        # print("texts:", texts)
        
        scores = scorer.get_perplexity(texts, batch_size=batch_size)
        # print("scores:", scores)
        
        # 候補の中から1つを焼きなまし法の確率的受容ルールで選ぶ
        for i, (cand_seq, cand_score) in enumerate(zip(neighbor_candidates, scores)):
            delta = cand_score - current_scores[i]
            accept_prob = math.exp(-delta / temperature) if delta > 0 else 1.0
                
            # スコアが良ければ必ず受容
            if (itr==0) or (random.random() < accept_prob):
                current_scores[i] = cand_score
                current_seqs[i] = cand_seq

        # ベストの更新
        # currnet_scoresのリストの最小値を取得
        if np.min(current_scores) < best_score:
            # current_scoresの最小値のインデックスを取得
            idx = np.argmin(current_scores)
            
            best_score = current_scores[idx]
            best_seq = current_seqs[idx]
            print(f"iter {itr}: best_score: {best_score}")
            print("best_seq:", best_seq)

        # 温度を下げる
        if itr % 10 == 0:
            temperature *= cooling_rate
        
        if itr % 1000 == 0:
            print(f"iter :{itr}, best_score: {best_score}, temperature: {temperature}")

            # current_seqsを結合して文字列保存
            current_seqs_text = [" ".join(seq) for seq in current_seqs]
            # current_seqsとcurrent_scoresのリストをdfとして保存
            df = pd.DataFrame(current_seqs_text)
            df["score"] = current_scores
            
            # indexとなっていたものをsequencre列に変更
            df = df.reset_index()
            df = df.rename(columns={"index": "sequence"})
            
            df.to_csv(f"current_texts.csv", index=False)
        if temperature < end_temperature:
            break
        
    return best_seq, best_score, scores_history, temp_history

# %%
def search_optimal_permutation(
    CFG,
    id: int, 
    scorer
):
    
    df = pd.read_csv(CFG.base_file_path)
    
    start = time.time()
    # 文字列を単語に分割
    words = df.loc[id,"text"].split()
    
    initial_sequence = words[:]
    print("--------初期配置の組み合わせ計算開始---------")
    initial_sequence, initial_score = shuffle_initialize(
        scorer=scorer,
        words=words
    )
    
    print(f"{id}th sample: {initial_sequence}")
    print(f"Elapsed time: {time.time() - start:.2f} sec")
    print(f"initial_score: {initial_score}")
    print("--------初期配置の組み合わせ計算終了---------")
    
    print("---------焼きなまし処理開始---------")
    best_sequence, best_score, scores_history, temp_history = search_annealing(
        scorer=scorer,
        initial_sequence=initial_sequence,
        temperature=CFG.temperature,
        end_temperature=CFG.end_temperature,
        cooling_rate=CFG.cooling_rate,
        iteration=CFG.iteration,
        batch_size=CFG.batch_size,
        neighbor_types=CFG.neighbor_types
    )
    print("---------焼きなまし処理終了---------")
    
    print(f"{id}th sample: {best_sequence}")
    print(f"Elapsed time: {time.time() - start:.2f} sec")
    print(f"best_score: {best_score}")
    
    plot_score_and_temperature(scores_history, temp_history)
    
    return best_sequence, best_score

# %%
# 文字列型にのみダブルクォーテーションを付ける関数
def add_quotes_to_strings(value):
    if isinstance(value, str):  # 文字列型の場合
        return f'"{value}"'
    return value  # それ以外はそのまま

# %%
# LOAD GEMMA SCORER
scorer = PerplexityCalculator(f'{CFG.path}/gemma_2_9b')
# Out:
# cuda
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
# scorer.clear_gpu_memory()

# %%
for i in [4]:
    
    print(f"Processing {i}th sample")
    best_sequence, best_score = search_optimal_permutation(
        CFG,
        id=i,
        scorer=scorer,
    )
    
    print("Best sequence:", best_sequence)
    print("Best score:", best_score)
    sub_df.loc[i, "best_value"] = best_score
    sub_df.loc[i, "text"] = " ".join(best_sequence)
# Out:
# Processing 4th sample
# --------初期配置の組み合わせ計算開始---------
# 4th sample: ['kaggle', 'of', 'paper', 'hohoho', 'peppermint', 'card', 'toy', 'eggnog', 'season', 'merry', 'snowglobe', 'wrapping', 'that', 'from', 'wonder', 'we', 'as', 'night', 'cookie', 'hope', 'and', 'star', 'puzzle', 'dream', 'wreath', 'game', 'not', 'chocolate', 'to', 'the', 'fireplace', 'have', 'angel', 'candy', 'peace', 'bow', 'it', 'fruitcake', 'candle', 'believe', 'joy', 'poinsettia', 'milk', 'wish', 'workshop', 'with', 'greeting', 'you', 'doll', 'in']
# Elapsed time: 0.76 sec
# initial_score: 1745.582779603376
# --------初期配置の組み合わせ計算終了---------
# ---------焼きなまし処理開始---------
# current_seq: ['kaggle', 'of', 'paper', 'hohoho', 'peppermint', 'card', 'toy', 'eggnog', 'season', 'merry', 'snowglobe', 'wrapping', 'that', 'from', 'wonder', 'we', 'as', 'night', 'cookie', 'hope', 'and', 'star', 'puzzle', 'dream', 'wreath', 'game', 'not', 'chocolate', 'to', 'the', 'fireplace', 'have', 'angel', 'candy', 'peace', 'bow', 'it', 'fruitcake', 'candle', 'believe', 'joy', 'poinsettia', 'milk', 'wish', 'workshop', 'with', 'greeting', 'you', 'doll', 'in']
# current_score: 1745.582779603376
# current_seq: ['chocolate', 'wrapping', 'that', 'not', 'paper', 'peppermint', 'candy', 'peace', 'you', 'puzzle', 'of', 'have', 'wish', 'from', 'candle', 'to', 'kaggle', 'milk', 'fireplace', 'season', 'toy', 'angel', 'eggnog', 'it', 'wonder', 'night', 'bow', 'doll', 'joy', 'cookie', 'wreath', 'snowglobe', 'and', 'merry', 'star', 'as', 'card', 'hohoho', 'poinsettia', 'in', 'fruitcake', 'greeting', 'the', 'believe', 'we', 'hope', 'dream', 'game', 'with', 'workshop']
# current_score: 1793.9721167586677
# current_seq: ['puzzle', 'not', 'toy', 'dream', 'wonder', 'fruitcake', 'as', 'that', 'angel', 'hohoho', 'candle', 'bow', 'we', 'joy', 'wreath', 'night', 'kaggle', 'the', 'paper', 'candy', 'hope', 'and', 'with', 'you', 'poinsettia', 'of', 'believe', 'snowglobe', 'game', 'season', 'greeting', 'wrapping', 'it', 'milk', 'have', 'wish', 'cookie', 'in', 'doll', 'from', 'chocolate', 'peace', 'workshop', 'eggnog', 'star', 'merry', 'peppermint', 'to', 'card', 'fireplace']
# current_score: 1865.4358415938036
# current_seq: ['chocolate', 'angel', 'kaggle', 'wrapping', 'from', 'candle', 'milk', 'night', 'you', 'peppermint', 'in', 'wreath', 'and', 'greeting', 'card', 'snowglobe', 'wish', 'candy', 'with', 'doll', 'eggnog', 'have', 'we', 'workshop', 'hope', 'peace', 'bow', 'as', 'star', 'not', 'fruitcake', 'paper', 'to', 'of', 'cookie', 'poinsettia', 'dream', 'season', 'the', 'game', 'that', 'merry', 'hohoho', 'wonder', 'puzzle', 'joy', 'believe', 'toy', 'it', 'fireplace']
# current_score: 2024.911449616353
# current_seq: ['the', 'chocolate', 'toy', 'greeting', 'we', 'milk', 'bow', 'from', 'of', 'doll', 'candy', 'wish', 'it', 'and', 'that', 'cookie', 'wreath', 'merry', 'you', 'game', 'as', 'puzzle', 'star', 'paper', 'poinsettia', 'candle', 'snowglobe', 'wrapping', 'in', 'hohoho', 'fruitcake', 'season', 'wonder', 'night', 'to', 'angel', 'joy', 'peace', 'workshop', 'card', 'have', 'hope', 'kaggle', 'believe', 'peppermint', 'not', 'eggnog', 'dream', 'fireplace', 'with']
# current_score: 2130.3946005086336
# current_seq: ['wonder', 'of', 'chocolate', 'workshop', 'wrapping', 'wreath', 'bow', 'it', 'cookie', 'joy', 'candy', 'hope', 'paper', 'eggnog', 'card', 'have', 'milk', 'fruitcake', 'season', 'hohoho', 'star', 'game', 'with', 'kaggle', 'we', 'from', 'greeting', 'dream', 'to', 'candle', 'and', 'poinsettia', 'believe', 'peppermint', 'toy', 'not', 'doll', 'in', 'snowglobe', 'angel', 'night', 'as', 'the', 'puzzle', 'wish', 'peace', 'fireplace', 'that', 'you', 'merry']
# current_score: 1646.2413521768196
# current_seq: ['of', 'greeting', 'milk', 'that', 'fruitcake', 'peace', 'paper', 'and', 'workshop', 'hohoho', 'game', 'believe', 'poinsettia', 'puzzle', 'you', 'night', 'wrapping', 'peppermint', 'from', 'toy', 'dream', 'not', 'wonder', 'cookie', 'merry', 'joy', 'have', 'candy', 'snowglobe', 'wreath', 'we', 'hope', 'card', 'it', 'star', 'wish', 'with', 'in', 'to', 'bow', 'angel', 'chocolate', 'season', 'doll', 'kaggle', 'as', 'eggnog', 'candle', 'fireplace', 'the']
# current_score: 2024.911449616353
# current_seq: ['in', 'kaggle', 'the', 'cookie', 'from', 'you', 'wrapping', 'greeting', 'fruitcake', 'that', 'doll', 'wreath', 'peace', 'dream', 'of', 'candy', 'joy', 'wonder', 'season', 'hohoho', 'to', 'fireplace', 'puzzle', 'game', 'chocolate', 'night', 'it', 'with', 'poinsettia', 'peppermint', 'not', 'star', 'paper', 'candle', 'workshop', 'bow', 'toy', 'we', 'angel', 'eggnog', 'snowglobe', 'and', 'have', 'card', 'hope', 'wish', 'believe', 'as', 'milk', 'merry']
# current_score: 2461.6662819146695
# current_seq: ['with', 'eggnog', 'angel', 'the', 'that', 'peace', 'milk', 'doll', 'poinsettia', 'wrapping', 'toy', 'snowglobe', 'bow', 'and', 'dream', 'from', 'puzzle', 'fireplace', 'wonder', 'night', 'game', 'fruitcake', 'star', 'hohoho', 'we', 'you', 'chocolate', 'to', 'in', 'it', 'candy', 'season', 'cookie', 'wreath', 'card', 'of', 'have', 'not', 'greeting', 'kaggle', 'workshop', 'joy', 'candle', 'paper', 'merry', 'peppermint', 'believe', 'hope', 'wish', 'as']
# current_score: 1793.9721167586677
# current_seq: ['puzzle', 'have', 'joy', 'paper', 'merry', 'dream', 'chocolate', 'star', 'wreath', 'milk', 'that', 'hope', 'of', 'candle', 'with', 'snowglobe', 'angel', 'and', 'poinsettia', 'it', 'eggnog', 'season', 'cookie', 'kaggle', 'as', 'card', 'to', 'wonder', 'believe', 'workshop', 'wrapping', 'night', 'toy', 'candy', 'bow', 'hohoho', 'peppermint', 'peace', 'not', 'greeting', 'you', 'wish', 'we', 'in', 'doll', 'the', 'fruitcake', 'fireplace', 'game', 'from']
# current_score: 1725.2461242290015
# current_seq: ['paper', 'card', 'it', 'candle', 'wonder', 'hope', 'season', 'chocolate', 'game', 'with', 'wish', 'fireplace', 'hohoho', 'bow', 'puzzle', 'have', 'workshop', 'joy', 'dream', 'merry', 'fruitcake', 'wreath', 'angel', 'as', 'not', 'candy', 'kaggle', 'poinsettia', 'we', 'in', 'from', 'night', 'and', 'greeting', 'cookie', 'doll', 'snowglobe', 'of', 'wrapping', 'the', 'to', 'peppermint', 'you', 'believe', 'toy', 'milk', 'eggnog', 'that', 'peace', 'star']
# current_score: 2113.8157381974315
# current_seq: ['game', 'that', 'card', 'season', 'the', 'candle', 'wrapping', 'doll', 'wonder', 'wish', 'dream', 'bow', 'we', 'greeting', 'paper', 'milk', 'night', 'you', 'snowglobe', 'joy', 'wreath', 'cookie', 'fireplace', 'of', 'poinsettia', 'chocolate', 'hope', 'eggnog', 'it', 'merry', 'from', 'candy', 'angel', 'fruitcake', 'as', 'peace', 'not', 'puzzle', 'and', 'toy', 'kaggle', 'star', 'workshop', 'with', 'in', 'hohoho', 'believe', 'peppermint', 'have', 'to']
# current_score: 2703.611497823697
# current_seq: ['angel', 'as', 'peppermint', 'puzzle', 'merry', 'milk', 'to', 'doll', 'candle', 'hope', 'hohoho', 'season', 'believe', 'bow', 'not', 'poinsettia', 'wish', 'fireplace', 'of', 'kaggle', 'in', 'dream', 'the', 'card', 'greeting', 'toy', 'joy', 'workshop', 'it', 'with', 'night', 'wreath', 'eggnog', 'peace', 'chocolate', 'candy', 'paper', 'star', 'that', 'cookie', 'have', 'you', 'we', 'wonder', 'and', 'snowglobe', 'game', 'wrapping', 'from', 'fruitcake']
# current_score: 2312.521461518121
# current_seq: ['it', 'candy', 'in', 'and', 'milk', 'have', 'of', 'season', 'with', 'game', 'candle', 'as', 'star', 'hope', 'poinsettia', 'peace', 'joy', 'we', 'wish', 'puzzle', 'paper', 'from', 'toy', 'that', 'chocolate', 'doll', 'greeting', 'wrapping', 'bow', 'wonder', 'workshop', 'fruitcake', 'merry', 'you', 'kaggle', 'the', 'snowglobe', 'hohoho', 'cookie', 'eggnog', 'card', 'to', 'peppermint', 'dream', 'fireplace', 'night', 'believe', 'angel', 'not', 'wreath']
# current_score: 1829.355046299521
# current_seq: ['candle', 'cookie', 'angel', 'to', 'the', 'kaggle', 'believe', 'wreath', 'bow', 'peace', 'merry', 'have', 'we', 'hohoho', 'eggnog', 'poinsettia', 'and', 'wish', 'wonder', 'as', 'you', 'from', 'hope', 'dream', 'greeting', 'toy', 'fireplace', 'season', 'wrapping', 'candy', 'night', 'card', 'puzzle', 'milk', 'chocolate', 'star', 'with', 'snowglobe', 'game', 'fruitcake', 'it', 'of', 'that', 'workshop', 'joy', 'paper', 'doll', 'not', 'peppermint', 'in']
# current_score: 2163.9434338520923
# current_seq: ['puzzle', 'we', 'hohoho', 'merry', 'not', 'wish', 'the', 'season', 'it', 'card', 'greeting', 'with', 'hope', 'wreath', 'wrapping', 'wonder', 'candy', 'paper', 'workshop', 'you', 'game', 'have', 'peppermint', 'eggnog', 'of', 'kaggle', 'to', 'snowglobe', 'and', 'candle', 'that', 'star', 'doll', 'dream', 'angel', 'bow', 'believe', 'joy', 'as', 'cookie', 'chocolate', 'night', 'from', 'toy', 'fireplace', 'poinsettia', 'milk', 'peace', 'in', 'fruitcake']
# current_score: 1493.07607396205
# current_seq: ['you', 'star', 'season', 'doll', 'merry', 'hohoho', 'wonder', 'from', 'it', 'believe', 'dream', 'joy', 'angel', 'we', 'that', 'the', 'to', 'workshop', 'fireplace', 'chocolate', 'night', 'paper', 'hope', 'snowglobe', 'kaggle', 'candy', 'eggnog', 'peace', 'toy', 'as', 'with', 'game', 'wish', 'not', 'greeting', 'and', 'card', 'of', 'have', 'puzzle', 'fruitcake', 'milk', 'peppermint', 'in', 'poinsettia', 'wreath', 'bow', 'cookie', 'wrapping', 'candle']
# current_score: 2206.623393777401
# current_seq: ['have', 'wish', 'wrapping', 'card', 'candle', 'game', 'dream', 'that', 'toy', 'candy', 'joy', 'you', 'hohoho', 'in', 'of', 'snowglobe', 'wonder', 'fireplace', 'peace', 'bow', 'chocolate', 'wreath', 'as', 'fruitcake', 'season', 'believe', 'and', 'to', 'doll', 'with', 'greeting', 'it', 'poinsettia', 'not', 'kaggle', 'puzzle', 'hope', 'the', 'star', 'we', 'workshop', 'night', 'peppermint', 'paper', 'milk', 'eggnog', 'angel', 'from', 'merry', 'cookie']
# current_score: 1970.2929179626208
# current_seq: ['with', 'merry', 'kaggle', 'game', 'it', 'chocolate', 'from', 'to', 'workshop', 'fruitcake', 'and', 'poinsettia', 'star', 'candle', 'have', 'hohoho', 'as', 'night', 'puzzle', 'candy', 'paper', 'not', 'card', 'dream', 'that', 'wrapping', 'angel', 'eggnog', 'wreath', 'season', 'cookie', 'fireplace', 'the', 'peppermint', 'of', 'peace', 'in', 'milk', 'doll', 'believe', 'snowglobe', 'you', 'we', 'bow', 'wish', 'greeting', 'hope', 'toy', 'wonder', 'joy']
# current_score: 1546.5006307786239
# current_seq: ['not', 'joy', 'you', 'it', 'wrapping', 'and', 'doll', 'from', 'game', 'hohoho', 'in', 'eggnog', 'peace', 'as', 'wonder', 'we', 'the', 'fruitcake', 'peppermint', 'of', 'angel', 'that', 'fireplace', 'wish', 'card', 'puzzle', 'candle', 'paper', 'wreath', 'dream', 'merry', 'star', 'have', 'chocolate', 'greeting', 'snowglobe', 'believe', 'workshop', 'to', 'cookie', 'kaggle', 'hope', 'season', 'night', 'toy', 'bow', 'candy', 'milk', 'with', 'poinsettia']
# current_score: 2180.9154525530494
# current_seq: ['from', 'hohoho', 'peace', 'peppermint', 'not', 'cookie', 'chocolate', 'puzzle', 'season', 'star', 'bow', 'greeting', 'joy', 'angel', 'night', 'it', 'fruitcake', 'to', 'that', 'of', 'card', 'have', 'believe', 'kaggle', 'hope', 'toy', 'the', 'doll', 'fireplace', 'poinsettia', 'milk', 'candy', 'candle', 'wish', 'snowglobe', 'merry', 'you', 'wrapping', 'as', 'wonder', 'with', 'we', 'in', 'dream', 'wreath', 'and', 'eggnog', 'workshop', 'game', 'paper']
# current_score: 1469.928074993662
# current_seq: ['angel', 'wonder', 'have', 'bow', 'eggnog', 'fruitcake', 'game', 'hope', 'that', 'to', 'candy', 'candle', 'star', 'doll', 'chocolate', 'milk', 'snowglobe', 'we', 'wish', 'from', 'the', 'paper', 'wreath', 'it', 'peace', 'joy', 'and', 'puzzle', 'wrapping', 'night', 'dream', 'card', 'peppermint', 'as', 'hohoho', 'of', 'kaggle', 'in', 'fireplace', 'greeting', 'you', 'not', 'cookie', 'with', 'toy', 'merry', 'season', 'believe', 'workshop', 'poinsettia']
# current_score: 1793.9721167586677
# current_seq: ['have', 'bow', 'game', 'night', 'you', 'workshop', 'wish', 'hope', 'season', 'wreath', 'joy', 'angel', 'it', 'wrapping', 'not', 'wonder', 'with', 'cookie', 'from', 'candy', 'fireplace', 'and', 'the', 'toy', 'poinsettia', 'fruitcake', 'puzzle', 'to', 'in', 'paper', 'star', 'candle', 'doll', 'merry', 'hohoho', 'of', 'kaggle', 'milk', 'peace', 'peppermint', 'believe', 'greeting', 'chocolate', 'dream', 'we', 'eggnog', 'snowglobe', 'that', 'card', 'as']
# current_score: 2122.088979078394
# current_seq: ['game', 'puzzle', 'candle', 'with', 'the', 'wrapping', 'as', 'fireplace', 'and', 'dream', 'doll', 'card', 'it', 'bow', 'of', 'hope', 'cookie', 'paper', 'kaggle', 'workshop', 'merry', 'believe', 'have', 'season', 'from', 'wonder', 'chocolate', 'star', 'greeting', 'not', 'joy', 'to', 'we', 'snowglobe', 'wreath', 'wish', 'fruitcake', 'angel', 'candy', 'milk', 'night', 'toy', 'peppermint', 'you', 'in', 'that', 'hohoho', 'poinsettia', 'peace', 'eggnog']
# current_score: 1932.184003221256
# current_seq: ['it', 'greeting', 'believe', 'not', 'hohoho', 'and', 'wish', 'merry', 'milk', 'cookie', 'fruitcake', 'snowglobe', 'we', 'that', 'poinsettia', 'joy', 'candle', 'star', 'in', 'with', 'game', 'paper', 'peace', 'doll', 'wonder', 'wrapping', 'hope', 'the', 'card', 'wreath', 'peppermint', 'from', 'workshop', 'dream', 'angel', 'season', 'candy', 'chocolate', 'as', 'to', 'kaggle', 'have', 'fireplace', 'of', 'eggnog', 'bow', 'you', 'puzzle', 'toy', 'night']
# current_score: 1691.8768435211873
# current_seq: ['hohoho', 'toy', 'as', 'we', 'hope', 'from', 'merry', 'to', 'workshop', 'puzzle', 'in', 'and', 'with', 'fruitcake', 'angel', 'cookie', 'doll', 'wish', 'star', 'the', 'it', 'dream', 'you', 'wreath', 'eggnog', 'peace', 'fireplace', 'paper', 'that', 'not', 'kaggle', 'candy', 'wonder', 'have', 'milk', 'chocolate', 'joy', 'card', 'of', 'night', 'poinsettia', 'wrapping', 'candle', 'snowglobe', 'greeting', 'bow', 'season', 'game', 'believe', 'peppermint']
# current_score: 1218.613175800609
# current_seq: ['game', 'in', 'candle', 'merry', 'cookie', 'the', 'paper', 'card', 'it', 'from', 'fireplace', 'have', 'poinsettia', 'that', 'not', 'snowglobe', 'wrapping', 'angel', 'you', 'of', 'believe', 'doll', 'greeting', 'wreath', 'with', 'to', 'bow', 'peppermint', 'hohoho', 'wonder', 'as', 'night', 'peace', 'fruitcake', 'and', 'dream', 'kaggle', 'toy', 'season', 'star', 'eggnog', 'milk', 'puzzle', 'joy', 'wish', 'candy', 'hope', 'workshop', 'chocolate', 'we']
# current_score: 2579.804113414313
# current_seq: ['game', 'chocolate', 'you', 'candy', 'to', 'the', 'angel', 'peppermint', 'not', 'of', 'wrapping', 'peace', 'in', 'dream', 'workshop', 'poinsettia', 'it', 'puzzle', 'cookie', 'and', 'that', 'fruitcake', 'joy', 'have', 'wonder', 'season', 'wreath', 'as', 'doll', 'candle', 'card', 'snowglobe', 'greeting', 'star', 'with', 'hohoho', 'hope', 'eggnog', 'we', 'milk', 'merry', 'believe', 'night', 'toy', 'from', 'wish', 'paper', 'bow', 'fireplace', 'kaggle']
# current_score: 2130.3946005086336
# current_seq: ['game', 'doll', 'dream', 'hohoho', 'greeting', 'wish', 'wonder', 'season', 'joy', 'as', 'hope', 'kaggle', 'toy', 'poinsettia', 'bow', 'we', 'in', 'paper', 'from', 'of', 'with', 'eggnog', 'the', 'believe', 'candle', 'fruitcake', 'night', 'merry', 'not', 'snowglobe', 'you', 'wrapping', 'star', 'workshop', 'candy', 'have', 'puzzle', 'peace', 'to', 'fireplace', 'and', 'peppermint', 'card', 'it', 'cookie', 'wreath', 'chocolate', 'angel', 'milk', 'that']
# current_score: 1652.6845586534514
# current_seq: ['paper', 'night', 'joy', 'poinsettia', 'of', 'card', 'snowglobe', 'it', 'wish', 'as', 'peppermint', 'that', 'you', 'from', 'cookie', 'hohoho', 'greeting', 'and', 'to', 'merry', 'puzzle', 'have', 'fruitcake', 'bow', 'angel', 'season', 'eggnog', 'wonder', 'not', 'toy', 'milk', 'fireplace', 'game', 'believe', 'dream', 'chocolate', 'the', 'hope', 'star', 'candle', 'wreath', 'with', 'in', 'doll', 'we', 'kaggle', 'workshop', 'candy', 'peace', 'wrapping']
# current_score: 1577.0026226114692
# current_seq: ['peace', 'with', 'bow', 'wish', 'hohoho', 'angel', 'wreath', 'have', 'season', 'eggnog', 'hope', 'doll', 'kaggle', 'not', 'fruitcake', 'the', 'peppermint', 'workshop', 'and', 'to', 'milk', 'that', 'greeting', 'merry', 'as', 'dream', 'game', 'paper', 'poinsettia', 'candle', 'of', 'believe', 'candy', 'chocolate', 'it', 'night', 'joy', 'from', 'star', 'we', 'wrapping', 'in', 'fireplace', 'puzzle', 'wonder', 'toy', 'snowglobe', 'card', 'cookie', 'you']
# current_score: 2163.9434338520923
# current_seq: ['peace', 'doll', 'to', 'it', 'poinsettia', 'paper', 'toy', 'angel', 'peppermint', 'wonder', 'cookie', 'believe', 'candy', 'bow', 'as', 'card', 'that', 'not', 'greeting', 'in', 'game', 'of', 'kaggle', 'dream', 'eggnog', 'candle', 'night', 'and', 'hohoho', 'wish', 'puzzle', 'milk', 'wrapping', 'have', 'star', 'joy', 'fruitcake', 'snowglobe', 'hope', 'fireplace', 'chocolate', 'merry', 'wreath', 'the', 'workshop', 'season', 'we', 'from', 'with', 'you']
# current_score: 2009.1534636978986
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# iter 0: best_score: 1262.217028265557
# best_seq: ['believe', 'card', 'paper', 'merry', 'that', 'fruitcake', 'joy', 'toy', 'hohoho', 'bow', 'it', 'doll', 'wrapping', 'as', 'poinsettia', 'have', 'chocolate', 'we', 'in', 'of', 'you', 'star', 'game', 'wish', 'candy', 'wonder', 'cookie', 'to', 'greeting', 'peppermint', 'puzzle', 'snowglobe', 'fireplace', 'milk', 'the', 'not', 'candle', 'night', 'with', 'hope', 'from', 'season', 'and', 'peace', 'eggnog', 'kaggle', 'wreath', 'workshop', 'angel', 'dream']
# iter :0, best_score: 1262.217028265557, temperature: 99.99
# iter 2: best_score: 1135.8723783859068
# best_seq: ['peppermint', 'paper', 'merry', 'that', 'fruitcake', 'joy', 'toy', 'hohoho', 'bow', 'it', 'doll', 'wrapping', 'as', 'poinsettia', 'have', 'chocolate', 'we', 'in', 'of', 'you', 'star', 'game', 'wish', 'candy', 'wonder', 'cookie', 'to', 'greeting', 'believe', 'puzzle', 'snowglobe', 'fireplace', 'milk', 'the', 'card', 'not', 'candle', 'night', 'with', 'hope', 'from', 'season', 'and', 'peace', 'eggnog', 'kaggle', 'wreath', 'workshop', 'angel', 'dream']
# iter 12: best_score: 1105.234158889827
# best_seq: ['poinsettia', 'believe', 'paper', 'merry', 'that', 'fruitcake', 'joy', 'toy', 'hohoho', 'from', 'star', 'wrapping', 'as', 'have', 'chocolate', 'we', 'in', 'of', 'you', 'doll', 'game', 'wish', 'candy', 'wonder', 'cookie', 'to', 'greeting', 'peppermint', 'puzzle', 'snowglobe', 'fireplace', 'bow', 'milk', 'the', 'card', 'not', 'candle', 'night', 'with', 'hope', 'season', 'and', 'peace', 'it', 'eggnog', 'kaggle', 'wreath', 'workshop', 'angel', 'dream']
# iter 41: best_score: 1100.9252592553103
# best_seq: ['peppermint', 'paper', 'merry', 'that', 'fruitcake', 'joy', 'toy', 'hohoho', 'bow', 'poinsettia', 'it', 'doll', 'wrapping', 'as', 'have', 'chocolate', 'we', 'in', 'of', 'you', 'star', 'game', 'wish', 'candy', 'wonder', 'cookie', 'to', 'greeting', 'snowglobe', 'fireplace', 'milk', 'believe', 'card', 'not', 'candle', 'with', 'night', 'hope', 'from', 'peace', 'and', 'eggnog', 'kaggle', 'puzzle', 'the', 'wreath', 'season', 'workshop', 'angel', 'dream']
# iter 48: best_score: 1062.893303177624
# best_seq: ['believe', 'merry', 'eggnog', 'that', 'candy', 'joy', 'toy', 'wrapping', 'season', 'bow', 'it', 'doll', 'and', 'hope', 'have', 'we', 'greeting', 'wreath', 'chocolate', 'paper', 'you', 'star', 'wish', 'the', 'peace', 'wonder', 'as', 'game', 'to', 'peppermint', 'dream', 'puzzle', 'snowglobe', 'milk', 'fruitcake', 'night', 'in', 'not', 'angel', 'candle', 'card', 'with', 'fireplace', 'of', 'cookie', 'from', 'hohoho', 'kaggle', 'workshop', 'poinsettia']
# iter 51: best_score: 1038.271406328768
# best_seq: ['believe', 'merry', 'eggnog', 'that', 'candy', 'joy', 'toy', 'wrapping', 'season', 'bow', 'it', 'doll', 'and', 'hope', 'have', 'we', 'greeting', 'wreath', 'chocolate', 'paper', 'you', 'star', 'the', 'peace', 'wonder', 'as', 'game', 'to', 'peppermint', 'dream', 'puzzle', 'snowglobe', 'milk', 'fruitcake', 'night', 'in', 'not', 'angel', 'candle', 'wish', 'card', 'with', 'fireplace', 'of', 'cookie', 'from', 'hohoho', 'kaggle', 'workshop', 'poinsettia']
# iter 58: best_score: 1022.1745001752669
# best_seq: ['merry', 'eggnog', 'that', 'joy', 'believe', 'toy', 'wrapping', 'season', 'bow', 'it', 'and', 'hope', 'have', 'we', 'greeting', 'wreath', 'chocolate', 'paper', 'you', 'star', 'the', 'peace', 'wonder', 'as', 'candy', 'game', 'to', 'peppermint', 'dream', 'puzzle', 'doll', 'snowglobe', 'milk', 'fruitcake', 'night', 'in', 'not', 'angel', 'candle', 'wish', 'card', 'with', 'fireplace', 'of', 'cookie', 'from', 'hohoho', 'kaggle', 'workshop', 'poinsettia']
# iter 61: best_score: 1002.4038556569602
# best_seq: ['merry', 'eggnog', 'that', 'joy', 'believe', 'toy', 'wrapping', 'season', 'bow', 'it', 'and', 'hope', 'have', 'we', 'greeting', 'wreath', 'chocolate', 'paper', 'you', 'star', 'the', 'peace', 'wonder', 'as', 'candy', 'game', 'to', 'peppermint', 'dream', 'puzzle', 'doll', 'snowglobe', 'milk', 'fruitcake', 'night', 'in', 'not', 'cookie', 'angel', 'candle', 'wish', 'card', 'with', 'fireplace', 'of', 'from', 'hohoho', 'kaggle', 'workshop', 'poinsettia']
# iter 70: best_score: 971.5631312699539
# best_seq: ['merry', 'eggnog', 'that', 'joy', 'believe', 'toy', 'season', 'bow', 'it', 'and', 'hope', 'have', 'we', 'candy', 'wreath', 'chocolate', 'paper', 'you', 'star', 'the', 'peace', 'wonder', 'as', 'greeting', 'game', 'to', 'peppermint', 'dream', 'puzzle', 'doll', 'angel', 'wrapping', 'fruitcake', 'night', 'in', 'candle', 'not', 'cookie', 'snowglobe', 'milk', 'wish', 'card', 'with', 'fireplace', 'of', 'from', 'hohoho', 'kaggle', 'workshop', 'poinsettia']
# iter 85: best_score: 949.0568955746459
# best_seq: ['merry', 'eggnog', 'that', 'joy', 'believe', 'toy', 'season', 'it', 'hope', 'have', 'we', 'candy', 'wreath', 'angel', 'paper', 'you', 'star', 'the', 'peace', 'wonder', 'as', 'greeting', 'game', 'to', 'and', 'peppermint', 'dream', 'puzzle', 'doll', 'chocolate', 'of', 'wrapping', 'fruitcake', 'night', 'in', 'candle', 'not', 'cookie', 'snowglobe', 'milk', 'wish', 'card', 'with', 'fireplace', 'bow', 'from', 'hohoho', 'kaggle', 'workshop', 'poinsettia']
# iter 87: best_score: 941.6712762187423
# best_seq: ['merry', 'eggnog', 'that', 'joy', 'believe', 'toy', 'season', 'it', 'hope', 'have', 'we', 'candy', 'wreath', 'angel', 'paper', 'you', 'star', 'the', 'peace', 'wonder', 'as', 'greeting', 'game', 'to', 'and', 'peppermint', 'dream', 'doll', 'puzzle', 'chocolate', 'of', 'wrapping', 'fruitcake', 'night', 'in', 'candle', 'not', 'cookie', 'snowglobe', 'milk', 'wish', 'card', 'with', 'fireplace', 'bow', 'from', 'hohoho', 'kaggle', 'workshop', 'poinsettia']
# iter 144: best_score: 930.7004735480381
# best_seq: ['poinsettia', 'season', 'hope', 'with', 'puzzle', 'joy', 'toy', 'eggnog', 'bow', 'that', 'greeting', 'wish', 'as', 'and', 'cookie', 'the', 'angel', 'not', 'candle', 'of', 'wrapping', 'star', 'dream', 'doll', 'wreath', 'it', 'to', 'wonder', 'from', 'paper', 'peppermint', 'fruitcake', 'in', 'hohoho', 'milk', 'fireplace', 'believe', 'game', 'night', 'snowglobe', 'merry', 'chocolate', 'candy', 'you', 'have', 'we', 'peace', 'kaggle', 'workshop', 'card']
# iter 149: best_score: 867.5082310343188
# best_seq: ['poinsettia', 'season', 'hope', 'with', 'puzzle', 'joy', 'toy', 'eggnog', 'card', 'bow', 'that', 'greeting', 'wish', 'as', 'and', 'cookie', 'the', 'angel', 'not', 'candle', 'of', 'wrapping', 'star', 'dream', 'doll', 'wreath', 'it', 'to', 'wonder', 'from', 'paper', 'peppermint', 'fruitcake', 'in', 'hohoho', 'milk', 'fireplace', 'believe', 'game', 'night', 'snowglobe', 'merry', 'chocolate', 'candy', 'you', 'have', 'we', 'peace', 'kaggle', 'workshop']
# iter 157: best_score: 860.7572284206628
# best_seq: ['poinsettia', 'hohoho', 'season', 'hope', 'with', 'puzzle', 'joy', 'toy', 'eggnog', 'card', 'bow', 'that', 'greeting', 'wish', 'as', 'and', 'cookie', 'the', 'angel', 'not', 'candle', 'of', 'wrapping', 'star', 'dream', 'doll', 'wreath', 'it', 'to', 'wonder', 'from', 'paper', 'peppermint', 'fruitcake', 'in', 'milk', 'fireplace', 'believe', 'game', 'night', 'snowglobe', 'merry', 'chocolate', 'candy', 'you', 'have', 'we', 'peace', 'kaggle', 'workshop']
# iter 268: best_score: 844.108676557209
# best_seq: ['wreath', 'believe', 'star', 'not', 'candle', 'candy', 'peace', 'kaggle', 'workshop', 'and', 'fireplace', 'with', 'we', 'have', 'the', 'you', 'paper', 'it', 'toy', 'of', 'joy', 'that', 'night', 'dream', 'in', 'game', 'milk', 'chocolate', 'bow', 'poinsettia', 'peppermint', 'season', 'as', 'merry', 'card', 'from', 'wish', 'to', 'fruitcake', 'wrapping', 'puzzle', 'angel', 'greeting', 'wonder', 'eggnog', 'snowglobe', 'hohoho', 'doll', 'cookie', 'hope']
# iter 271: best_score: 824.5549201253252
# best_seq: ['wreath', 'believe', 'star', 'not', 'candle', 'candy', 'kaggle', 'workshop', 'and', 'fireplace', 'with', 'we', 'have', 'peace', 'the', 'you', 'paper', 'it', 'toy', 'of', 'joy', 'that', 'night', 'puzzle', 'in', 'game', 'milk', 'chocolate', 'bow', 'poinsettia', 'peppermint', 'season', 'as', 'merry', 'card', 'from', 'wish', 'to', 'fruitcake', 'wrapping', 'dream', 'angel', 'greeting', 'wonder', 'eggnog', 'snowglobe', 'hohoho', 'doll', 'cookie', 'hope']
# iter 344: best_score: 818.1381828290899
# best_seq: ['wreath', 'believe', 'paper', 'not', 'candle', 'candy', 'with', 'dream', 'and', 'we', 'you', 'wish', 'greeting', 'the', 'have', 'star', 'puzzle', 'joy', 'that', 'night', 'of', 'hope', 'in', 'game', 'milk', 'chocolate', 'bow', 'poinsettia', 'fruitcake', 'as', 'merry', 'card', 'from', 'wrapping', 'to', 'season', 'kaggle', 'wonder', 'peace', 'it', 'eggnog', 'angel', 'peppermint', 'workshop', 'snowglobe', 'doll', 'cookie', 'hohoho', 'fireplace', 'toy']
# iter 386: best_score: 799.1860322364524
# best_seq: ['wreath', 'believe', 'paper', 'not', 'candy', 'the', 'star', 'and', 'we', 'you', 'wish', 'greeting', 'card', 'have', 'dream', 'with', 'of', 'that', 'night', 'bow', 'in', 'game', 'milk', 'chocolate', 'puzzle', 'poinsettia', 'fruitcake', 'it', 'peace', 'as', 'angel', 'candle', 'joy', 'from', 'wrapping', 'to', 'season', 'kaggle', 'wonder', 'eggnog', 'merry', 'peppermint', 'workshop', 'hope', 'snowglobe', 'doll', 'cookie', 'hohoho', 'fireplace', 'toy']
# iter 398: best_score: 796.0703011721198
# best_seq: ['wreath', 'believe', 'paper', 'wrapping', 'candy', 'the', 'star', 'and', 'we', 'you', 'wish', 'greeting', 'card', 'have', 'dream', 'with', 'of', 'in', 'angel', 'bow', 'that', 'workshop', 'milk', 'chocolate', 'puzzle', 'poinsettia', 'game', 'fruitcake', 'it', 'peace', 'as', 'night', 'candle', 'joy', 'from', 'not', 'to', 'season', 'kaggle', 'wonder', 'eggnog', 'merry', 'toy', 'hope', 'snowglobe', 'doll', 'cookie', 'hohoho', 'fireplace', 'peppermint']
# iter 907: best_score: 792.9667171920373
# best_seq: ['wreath', 'merry', 'hohoho', 'to', 'season', 'greeting', 'poinsettia', 'the', 'wrapping', 'bow', 'fruitcake', 'it', 'chocolate', 'paper', 'candy', 'of', 'joy', 'peace', 'wish', 'eggnog', 'believe', 'in', 'we', 'peppermint', 'as', 'cookie', 'angel', 'not', 'star', 'have', 'snowglobe', 'hope', 'fireplace', 'with', 'kaggle', 'that', 'dream', 'workshop', 'toy', 'candle', 'card', 'from', 'doll', 'wonder', 'milk', 'puzzle', 'and', 'game', 'you', 'night']
# iter 913: best_score: 786.7958012412769
# best_seq: ['wreath', 'merry', 'hohoho', 'to', 'season', 'greeting', 'poinsettia', 'the', 'wrapping', 'bow', 'fruitcake', 'it', 'chocolate', 'paper', 'candy', 'of', 'joy', 'peace', 'wish', 'eggnog', 'believe', 'in', 'we', 'peppermint', 'as', 'cookie', 'angel', 'not', 'star', 'have', 'snowglobe', 'hope', 'fireplace', 'that', 'kaggle', 'with', 'dream', 'workshop', 'toy', 'candle', 'card', 'from', 'doll', 'wonder', 'milk', 'puzzle', 'and', 'game', 'you', 'night']
# iter :1000, best_score: 786.7958012412769, temperature: 98.99503337575031
# iter 1193: best_score: 744.923292506519
# best_seq: ['peppermint', 'toy', 'hohoho', 'bow', 'night', 'not', 'greeting', 'paper', 'chocolate', 'with', 'in', 'to', 'eggnog', 'the', 'you', 'we', 'card', 'fruitcake', 'from', 'wish', 'hope', 'wrapping', 'have', 'candy', 'merry', 'candle', 'season', 'as', 'cookie', 'fireplace', 'dream', 'wreath', 'that', 'star', 'milk', 'puzzle', 'poinsettia', 'of', 'believe', 'angel', 'peace', 'it', 'joy', 'wonder', 'workshop', 'game', 'and', 'kaggle', 'doll', 'snowglobe']
# iter :2000, best_score: 744.923292506519, temperature: 98.00996732739186
# iter :3000, best_score: 744.923292506519, temperature: 97.03470333764717
# iter :4000, best_score: 744.923292506519, temperature: 96.06914386955107
# iter 4941: best_score: 708.0395827712994
# best_seq: ['wreath', 'puzzle', 'fruitcake', 'wonder', 'chocolate', 'card', 'cookie', 'angel', 'toy', 'eggnog', 'dream', 'season', 'we', 'wish', 'kaggle', 'the', 'of', 'paper', 'poinsettia', 'snowglobe', 'fireplace', 'to', 'as', 'in', 'merry', 'it', 'game', 'peace', 'from', 'believe', 'star', 'doll', 'workshop', 'you', 'have', 'with', 'wrapping', 'night', 'milk', 'peppermint', 'joy', 'not', 'that', 'candy', 'and', 'bow', 'hope', 'greeting', 'hohoho', 'candle']
# iter 4943: best_score: 702.5295750239817
# best_seq: ['wreath', 'puzzle', 'fruitcake', 'wonder', 'chocolate', 'cookie', 'card', 'angel', 'toy', 'eggnog', 'dream', 'doll', 'we', 'wish', 'kaggle', 'the', 'of', 'paper', 'poinsettia', 'snowglobe', 'fireplace', 'to', 'as', 'in', 'merry', 'it', 'game', 'peace', 'from', 'believe', 'star', 'season', 'workshop', 'you', 'have', 'with', 'wrapping', 'night', 'milk', 'peppermint', 'joy', 'not', 'that', 'candy', 'and', 'bow', 'hope', 'greeting', 'hohoho', 'candle']
# iter :5000, best_score: 702.5295750239817, temperature: 95.11319235669531
# iter :6000, best_score: 702.5295750239817, temperature: 94.16675319357148
# iter :7000, best_score: 702.5295750239817, temperature: 93.22973172600908
# iter :8000, best_score: 702.5295750239817, temperature: 92.3020342417093
# iter 8235: best_score: 691.6378635020337
# best_seq: ['from', 'puzzle', 'not', 'eggnog', 'with', 'cookie', 'we', 'merry', 'to', 'it', 'greeting', 'candy', 'have', 'that', 'peppermint', 'joy', 'paper', 'game', 'believe', 'in', 'workshop', 'wrapping', 'hohoho', 'season', 'fireplace', 'bow', 'card', 'wreath', 'and', 'candle', 'the', 'milk', 'night', 'wish', 'you', 'wonder', 'chocolate', 'poinsettia', 'hope', 'angel', 'of', 'peace', 'fruitcake', 'snowglobe', 'dream', 'star', 'doll', 'kaggle', 'toy', 'as']
# iter :9000, best_score: 691.6378635020337, temperature: 91.38356796087267
# iter :10000, best_score: 691.6378635020337, temperature: 90.47424102692001
# iter :11000, best_score: 691.6378635020337, temperature: 89.57396249730601
# iter :12000, best_score: 691.6378635020337, temperature: 88.68264233442363
# iter :13000, best_score: 691.6378635020337, temperature: 87.80019139659957
# iter :14000, best_score: 691.6378635020337, temperature: 86.92652142917932
# iter :15000, best_score: 691.6378635020337, temperature: 86.06154505570036
# iter :16000, best_score: 691.6378635020337, temperature: 85.20517576915384
# iter :17000, best_score: 691.6378635020337, temperature: 84.35732792333285
# iter :18000, best_score: 691.6378635020337, temperature: 83.51791672426685
# iter :19000, best_score: 691.6378635020337, temperature: 82.6868582217415
# iter 19025: best_score: 688.941423011762
# best_seq: ['from', 'as', 'kaggle', 'the', 'that', 'in', 'to', 'with', 'not', 'night', 'eggnog', 'workshop', 'it', 'milk', 'joy', 'wrapping', 'toy', 'poinsettia', 'candle', 'wish', 'we', 'hope', 'believe', 'wreath', 'snowglobe', 'dream', 'and', 'season', 'wonder', 'chocolate', 'card', 'paper', 'fruitcake', 'hohoho', 'doll', 'have', 'star', 'of', 'candy', 'you', 'peace', 'merry', 'game', 'puzzle', 'angel', 'fireplace', 'bow', 'cookie', 'greeting', 'peppermint']
# iter 19026: best_score: 672.9821121368258
# best_seq: ['from', 'as', 'kaggle', 'the', 'that', 'in', 'to', 'with', 'not', 'night', 'eggnog', 'workshop', 'it', 'of', 'milk', 'joy', 'wrapping', 'toy', 'poinsettia', 'candle', 'wish', 'we', 'hope', 'believe', 'wreath', 'snowglobe', 'dream', 'and', 'season', 'wonder', 'chocolate', 'card', 'paper', 'fruitcake', 'hohoho', 'doll', 'have', 'star', 'candy', 'you', 'peace', 'merry', 'game', 'puzzle', 'angel', 'fireplace', 'bow', 'cookie', 'greeting', 'peppermint']
# iter 19036: best_score: 670.3584035283843
# best_seq: ['from', 'as', 'kaggle', 'the', 'that', 'in', 'to', 'with', 'not', 'night', 'eggnog', 'workshop', 'it', 'of', 'milk', 'joy', 'wrapping', 'toy', 'poinsettia', 'candle', 'wish', 'we', 'hope', 'believe', 'wreath', 'snowglobe', 'dream', 'and', 'season', 'wonder', 'chocolate', 'card', 'paper', 'fruitcake', 'hohoho', 'doll', 'have', 'candy', 'you', 'peace', 'merry', 'game', 'puzzle', 'angel', 'fireplace', 'bow', 'cookie', 'star', 'greeting', 'peppermint']
# iter :20000, best_score: 670.3584035283843, temperature: 81.8640693009024
# iter :21000, best_score: 670.3584035283843, temperature: 81.04946767394313
# iter :22000, best_score: 670.3584035283843, temperature: 80.24297187187518
# iter :23000, best_score: 670.3584035283843, temperature: 79.44450123638036
# iter :24000, best_score: 670.3584035283843, temperature: 78.65397591174425
# iter :25000, best_score: 670.3584035283843, temperature: 77.87131683686947
# iter 25033: best_score: 647.2005722905537
# best_seq: ['it', 'the', 'with', 'as', 'in', 'of', 'that', 'not', 'you', 'star', 'night', 'and', 'dream', 'wish', 'joy', 'from', 'cookie', 'candy', 'fireplace', 'to', 'merry', 'toy', 'paper', 'eggnog', 'season', 'hope', 'doll', 'have', 'game', 'angel', 'greeting', 'wreath', 'wonder', 'we', 'hohoho', 'fruitcake', 'peppermint', 'candle', 'peace', 'bow', 'milk', 'kaggle', 'workshop', 'chocolate', 'snowglobe', 'puzzle', 'believe', 'wrapping', 'card', 'poinsettia']
# iter 25048: best_score: 634.6825800645618
# best_seq: ['it', 'the', 'with', 'as', 'in', 'of', 'that', 'not', 'you', 'star', 'night', 'and', 'to', 'wish', 'joy', 'from', 'cookie', 'candy', 'fireplace', 'doll', 'dream', 'merry', 'toy', 'paper', 'eggnog', 'season', 'hope', 'have', 'game', 'angel', 'greeting', 'wreath', 'wonder', 'we', 'hohoho', 'fruitcake', 'peppermint', 'candle', 'peace', 'bow', 'milk', 'kaggle', 'workshop', 'chocolate', 'snowglobe', 'puzzle', 'believe', 'wrapping', 'card', 'poinsettia']
# iter :26000, best_score: 634.6825800645618, temperature: 77.09644573736895
# iter :27000, best_score: 634.6825800645618, temperature: 76.32928511773734
# iter :28000, best_score: 634.6825800645618, temperature: 75.56975825360098
# iter :29000, best_score: 634.6825800645618, temperature: 74.81778918404456
# iter :30000, best_score: 634.6825800645618, temperature: 74.07330270401374
# iter :31000, best_score: 634.6825800645618, temperature: 73.3362243567947
# iter :32000, best_score: 634.6825800645618, temperature: 72.60648042656676
# iter :33000, best_score: 634.6825800645618, temperature: 71.88399793103048
# iter :34000, best_score: 634.6825800645618, temperature: 71.16870461410866
# iter 34032: best_score: 627.2883040361144
# best_seq: ['wreath', 'have', 'fruitcake', 'candle', 'chocolate', 'eggnog', 'peppermint', 'it', 'that', 'angel', 'toy', 'wonder', 'believe', 'in', 'we', 'not', 'and', 'you', 'from', 'workshop', 'wish', 'cookie', 'star', 'snowglobe', 'doll', 'milk', 'hohoho', 'with', 'season', 'dream', 'wrapping', 'as', 'paper', 'joy', 'greeting', 'card', 'poinsettia', 'night', 'merry', 'peace', 'hope', 'to', 'kaggle', 'the', 'puzzle', 'of', 'candy', 'game', 'bow', 'fireplace']
# iter 34033: best_score: 612.7571861239999
# best_seq: ['wreath', 'have', 'fruitcake', 'candle', 'chocolate', 'eggnog', 'peppermint', 'it', 'that', 'angel', 'toy', 'wonder', 'workshop', 'in', 'we', 'not', 'and', 'you', 'from', 'believe', 'wish', 'cookie', 'star', 'snowglobe', 'doll', 'milk', 'hohoho', 'with', 'season', 'dream', 'wrapping', 'as', 'paper', 'joy', 'greeting', 'card', 'poinsettia', 'night', 'merry', 'peace', 'hope', 'to', 'kaggle', 'the', 'puzzle', 'of', 'candy', 'game', 'bow', 'fireplace']
# iter :35000, best_score: 612.7571861239999, temperature: 70.4605289387199
# iter :36000, best_score: 612.7571861239999, temperature: 69.75940007962392
# iter :37000, best_score: 612.7571861239999, temperature: 69.06524791633846
# iter :38000, best_score: 612.7571861239999, temperature: 68.37800302612655
# iter :39000, best_score: 612.7571861239999, temperature: 67.69759667705318
# iter :40000, best_score: 612.7571861239999, temperature: 67.02396082111166
# iter :41000, best_score: 612.7571861239999, temperature: 66.35702808741796
# iter :42000, best_score: 612.7571861239999, temperature: 65.69673177547297
# iter :43000, best_score: 612.7571861239999, temperature: 65.04300584849139
# iter :44000, best_score: 612.7571861239999, temperature: 64.39578492679802
# iter :45000, best_score: 612.7571861239999, temperature: 63.75500428128821
# iter :46000, best_score: 612.7571861239999, temperature: 63.12059982695498
# iter :47000, best_score: 612.7571861239999, temperature: 62.49250811647949
# iter :48000, best_score: 612.7571861239999, temperature: 61.87066633388571
# iter :49000, best_score: 612.7571861239999, temperature: 61.25501228825809
# iter :50000, best_score: 612.7571861239999, temperature: 60.64548440752177
# iter :51000, best_score: 612.7571861239999, temperature: 60.04202173228478
# iter :52000, best_score: 612.7571861239999, temperature: 59.44456390974156
# iter :53000, best_score: 612.7571861239999, temperature: 58.853051187636616
# iter :54000, best_score: 612.7571861239999, temperature: 58.267424408289116
# iter :55000, best_score: 612.7571861239999, temperature: 57.68762500267614
# iter 55281: best_score: 607.9886718701034
# best_seq: ['peppermint', 'bow', 'of', 'joy', 'hope', 'believe', 'from', 'wonder', 'workshop', 'cookie', 'eggnog', 'fruitcake', 'you', 'in', 'wrapping', 'not', 'paper', 'that', 'angel', 'we', 'the', 'chocolate', 'poinsettia', 'star', 'candy', 'game', 'card', 'candle', 'wreath', 'doll', 'kaggle', 'and', 'it', 'toy', 'snowglobe', 'season', 'hohoho', 'puzzle', 'merry', 'to', 'have', 'fireplace', 'as', 'night', 'with', 'peace', 'milk', 'greeting', 'dream', 'wish']
# iter :56000, best_score: 607.9886718701034, temperature: 57.113594984575364
# iter :57000, best_score: 607.9886718701034, temperature: 56.54527694476569
# iter :58000, best_score: 607.9886718701034, temperature: 55.98261404528578
# iter :59000, best_score: 607.9886718701034, temperature: 55.42555001374945
# iter :60000, best_score: 607.9886718701034, temperature: 54.874029137718196
# iter :61000, best_score: 607.9886718701034, temperature: 54.327996259128994
# iter :62000, best_score: 607.9886718701034, temperature: 53.787396768777974
# iter :63000, best_score: 607.9886718701034, temperature: 53.252176600859094
# iter :64000, best_score: 607.9886718701034, temperature: 52.722282227556676
# iter :65000, best_score: 607.9886718701034, temperature: 52.19766065369237
# iter :66000, best_score: 607.9886718701034, temperature: 51.67825941142479
# iter :67000, best_score: 607.9886718701034, temperature: 51.16402655500228
# iter :68000, best_score: 607.9886718701034, temperature: 50.6549106555678
# iter :69000, best_score: 607.9886718701034, temperature: 50.15086079601543
# iter :70000, best_score: 607.9886718701034, temperature: 49.651826565898126
# iter :71000, best_score: 607.9886718701034, temperature: 49.15775805638616
# iter 71248: best_score: 598.5626811957673
# best_seq: ['from', 'the', 'fruitcake', 'chocolate', 'eggnog', 'snowglobe', 'poinsettia', 'star', 'of', 'wonder', 'cookie', 'have', 'believe', 'joy', 'merry', 'paper', 'doll', 'greeting', 'season', 'it', 'and', 'you', 'dream', 'with', 'we', 'hope', 'that', 'candle', 'workshop', 'card', 'fireplace', 'bow', 'wrapping', 'wreath', 'night', 'not', 'game', 'as', 'peace', 'in', 'angel', 'wish', 'puzzle', 'to', 'candy', 'peppermint', 'milk', 'kaggle', 'toy', 'hohoho']
# iter :72000, best_score: 598.5626811957673, temperature: 48.668605855275544

# %%
sub_df

# %%
# 各セルに関数を適用
sub_df["text"] = sub_df["text"].astype(str)
sub_df = sub_df.applymap(add_quotes_to_strings)

# %%
sub_df[["id", "text"]].to_csv(f"{CFG.path}/out/submission_{ex_num}.csv", index=False, header=True, quoting=csv.QUOTE_NONE)
sub_df.to_csv(f"{CFG.path}/out/score_{ex_num}.csv", index=False, header=True, quoting=csv.QUOTE_NONE)

# %%
np.mean(sub_df["best_value"])
